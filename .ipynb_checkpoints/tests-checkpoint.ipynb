# %% [markdown]
# We run tests on some benchmark problems using standard RIPPERk

# %%
import numpy as np
import pandas as pd
import scipy

# %%
import uci_dataset as data

# %%
import random
random.seed(10)

# %%
# The results will depend on the random train-test split, so we average the accuracies over a certain number of repetitions
n_rep = 20

# %% [markdown]
# # Thyroid dataset

# %%
df = data.load_thyroid_disease()

# %%
df.columns
# Out:
# Index(['sick-euthyroid', 'age', 'sex', 'on_thyroxine', 'query_on_thyroxine',
#        'on_antithyroid_medication', 'thyroid_surgery', 'query_hypothyroid',
#        'query_hyperthyroid', 'pregnant', 'sick', 'tumor', 'lithium', 'goitre',
#        'TSH_measured', 'TSH', 'T3_measured', 'T3', 'TT4_measured', 'TT4',
#        'T4U_measured', 'T4U', 'FTI_measured', 'FTI', 'TBG_measured', 'TBG'],
#       dtype='object')

# %%
import wittgenstein2 as lw

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
X = df

# %%
X_train, X_test = train_test_split(df, test_size = 0.2)

# %%
X_train
# Out:
#      sick-euthyroid   age sex on_thyroxine query_on_thyroxine  \
# 383        negative  77.0   M            f                  f
# 1343       negative  69.0   F            f                  f
# 1720       negative  37.0   F            f                  f
# 2006       negative  25.0   F            f                  f
# 1058       negative  24.0   F            f                  f
# ...             ...   ...  ..          ...                ...
# 730        negative  73.0   M            f                  f
# 1684       negative  50.0   F            t                  f
# 2459       negative  39.0   F            f                  f
# 2923       negative  53.0   M            f                  f
# 2587       negative  68.0   F            f                  f
#
#      on_antithyroid_medication thyroid_surgery query_hypothyroid  \
# 383                          f               f                 f
# 1343                         f               f                 f
# 1720                         f               f                 t
# 2006                         f               f                 f
# 1058                         f               f                 f
# ...                        ...             ...               ...
# 730                          f               f                 f
# 1684                         f               f                 f
# 2459                         f               f                 f
# 2923                         f               f                 f
# 2587                         f               f                 f
#
#      query_hyperthyroid pregnant  ... T3_measured   T3 TT4_measured    TT4  \
# 383                   t        f  ...           y  1.7            y  106.0
# 1343                  f        f  ...           y  0.8            y   53.0
# 1720                  f        f  ...           y  0.9            y   87.0
# 2006                  f        f  ...           n  NaN            y  101.0
# 1058                  f        f  ...           n  NaN            n    NaN
# ...                 ...      ...  ...         ...  ...          ...    ...
# 730                   f        f  ...           y  1.3            y   44.0
# 1684                  f        f  ...           n  NaN            y  248.0
# 2459                  t        f  ...           n  NaN            n    NaN
# 2923                  f        f  ...           y  2.5            y   73.0
# 2587                  f        f  ...           y  2.0            y  112.0
#
#      T4U_measured   T4U FTI_measured    FTI TBG_measured   TBG
# 383             y  0.83            y  127.0            n   NaN
# 1343            y  0.86            y   61.0            n   NaN
# 1720            y  0.84            y  105.0            n   NaN
# 2006            y  1.11            y   93.0            n   NaN
# 1058            n   NaN            n    NaN            y  20.0
# ...           ...   ...          ...    ...          ...   ...
# 730             y  0.55            y   80.0            n   NaN
# 1684            y  1.50            y  165.0            n   NaN
# 2459            n   NaN            n    NaN            y  29.0
# 2923            y  0.92            y   79.0            n   NaN
# 2587            y  1.05            y  107.0            n   NaN
#
# [2530 rows x 26 columns]

# %%
X_train['sick-euthyroid'].unique()
# Out:
# array(['negative', 'sick-euthyroid'], dtype=object)

# %%
acc = []

for i in range(n_rep):
    X_train, X_test = train_test_split(df, test_size = 0.2)
    ripper_clf = lw.RIPPER(k=2, verbosity = 5)
    ripper_clf.fit(X_train, class_feat = 'sick-euthyroid', pos_class = 'sick-euthyroid')
    y_test = X_test['sick-euthyroid']
    score = ripper_clf.score(X_test, y_test)
    acc += [score]
    
np.mean(acc)
# Out:
# age: fit 93 unique vals into 10 bins
# TSH: fit 217 unique vals into 7 bins
# T3: fit 70 unique vals into 10 bins
# TT4: fit 260 unique vals into 10 bins
# T4U: fit 153 unique vals into 10 bins
# FTI: fit 264 unique vals into 10 bins
# TBG: fit 50 unique vals into 10 bins
# growing ruleset...
# initial model: []
#
# pos_growset 150 pos_pruneset 74
# neg_growset 1545 neg_pruneset 761
# growing rule from initial rule: [True]
# gain 248 T3=<0.9
# negs remaining: 60
# gain 16.2 TSH=<0.3
# negs remaining: 5
# gain 2.8 sex=F
# negs remaining: 1
# gain 1.1 on_thyroxine=f
# negs remaining: 0
# grew rule: [T3=<0.9^TSH=<0.3^sex=F^on_thyroxine=f]
# prune value of [T3=<0.9^TSH=<0.3^sex=F^on_thyroxine=f]: 0.85
# prune value of [T3=<0.9^TSH=<0.3^sex=F]: 0.85
# prune value of [T3=<0.9^TSH=<0.3]: 0.76
# prune value of [T3=<0.9]: 0.18
# pruned rule: [T3=<0.9^TSH=<0.3^sex=F]
# updated ruleset: [[T3=<0.9^TSH=<0.3^sex=F]]
#
# rule theory bits| [T3=<0.9^TSH=<0.3^sex=F] k 3 n 111 pr 0.03: 11.5 bits
# exceptions_bits| [[T3=<0.9^TSH=<0.3^sex=F]]:
#  N 2530 p 33 fp 2 fn 193: exceptions_bits 1001
# rule dl: 11.5
# updated theory dl: 11.5
# exceptions: 1001
# total dl: 1012
# mdl 1012 (diff 0 <= 64)
# examples remaining: 193 pos, 2304 neg
#
# pos_growset 129 pos_pruneset 64
# neg_growset 1543 neg_pruneset 761
# growing rule from initial rule: [True]
# gain 190 T3=<0.9
# negs remaining: 63
# gain 13.9 TSH=1.1-1.7
# negs remaining: 0
# grew rule: [T3=<0.9^TSH=1.1-1.7]
# prune value of [T3=<0.9^TSH=1.1-1.7]: 1
# prune value of [T3=<0.9]: 0.15
# pruned rule unchanged
# updated ruleset: [[T3=<0.9^TSH=<0.3^sex=F] V [T3=<0.9^TSH=1.1-1.7]]
#
# rule theory bits| [T3=<0.9^TSH=1.1-1.7] k 2 n 111 pr 0.02: 8.2 bits
# exceptions_bits| [[T3=<0.9^TSH=<0.3^sex=F] V [T3=<0.9^TSH=1.1-1.7]]:
#  N 2530 p 57 fp 2 fn 169: exceptions_bits 912
# rule dl: 8.2
# updated theory dl: 19.8
# exceptions: 912
# total dl: 932
# mdl 1012 (diff -80.06 <= 64)
# examples remaining: 169 pos, 2304 neg
#
# pos_growset 113 pos_pruneset 56
# neg_growset 1543 neg_pruneset 761
# growing rule from initial rule: [True]
# gain 148 T3=0.9-1.2
# negs remaining: 64
# gain 7.9 TSH=<0.3
# negs remaining: 18
# gain 3.5 T4U=0.83-0.88
# negs remaining: 1
# gain 0.58 age=70.0-76.0
# negs remaining: 0
# grew rule: [T3=0.9-1.2^TSH=<0.3^T4U=0.83-0.88^age=70.0-76.0]
# prune value of [T3=0.9-1.2^TSH=<0.3^T4U=0.83-0.88^age=70.0-76.0]: 1
# prune value of [T3=0.9-1.2^TSH=<0.3^T4U=0.83-0.88]: 0.33
# prune value of [T3=0.9-1.2^TSH=<0.3]: -0.12
# prune value of [T3=0.9-1.2]: -0.25
# pruned rule unchanged
# updated ruleset: ...[[T3=<0.9^TSH=1.1-1.7] V [T3=0.9-1.2^TSH=<0.3^T4U=0.83-0.88^age=70.0-76.0]]
#
# rule theory bits| [T3=0.9-1.2^TSH=<0.3^T4U=0.83-0.88^age=70.0-76.0] k 4 n 111 pr 0.04: 14.4 bits
# exceptions_bits| [[T3=<0.9^TSH=<0.3^sex=F] V [T3=<0.9^TSH=1.1-1.7]]...:
#  N 2530 p 60 fp 2 fn 166: exceptions_bits 901
# rule dl: 14.4
# updated theory dl: 34.2
# exceptions: 901
# total dl: 935
# mdl 932 (diff 3 <= 64)
# examples remaining: 166 pos, 2304 neg
#
# pos_growset 111 pos_pruneset 55
# neg_growset 1543 neg_pruneset 761
# growing rule from initial rule: [True]
# gain 158 T3=<0.9
# negs remaining: 67
# gain 10.9 TSH=0.3-0.7
# negs remaining: 1
# gain 0.69 sex=F
# negs remaining: 0
# grew rule: [T3=<0.9^TSH=0.3-0.7^sex=F]
# prune value of [T3=<0.9^TSH=0.3-0.7^sex=F]: 1
# prune value of [T3=<0.9^TSH=0.3-0.7]: 1
# prune value of [T3=<0.9]: 0.02
# pruned rule: [T3=<0.9^TSH=0.3-0.7]
# updated ruleset: ...[[T3=0.9-1.2^TSH=<0.3^T4U=0.83-0.88^age=70.0-76.0] V [T3=<0.9^TSH=0.3-0.7]]
#
# rule theory bits| [T3=<0.9^TSH=0.3-0.7] k 2 n 111 pr 0.02: 8.2 bits
# exceptions_bits| [[T3=<0.9^TSH=<0.3^sex=F] V [T3=<0.9^TSH=1.1-1.7]]...:
#  N 2530 p 75 fp 3 fn 152: exceptions_bits 851
# rule dl: 8.2
# updated theory dl: 42.4
# exceptions: 851
# total dl: 893
# mdl 932 (diff -38.6 <= 64)
# examples remaining: 152 pos, 2303 neg
#
# pos_growset 101 pos_pruneset 51
# neg_growset 1543 neg_pruneset 760
# growing rule from initial rule: [True]
# gain 127 T3=0.9-1.2
# negs remaining: 78
# gain 8.3 TSH=0.3-0.7
# negs remaining: 5
# gain 2.2 FTI=101.0-108.0
# negs remaining: 0
# grew rule: [T3=0.9-1.2^TSH=0.3-0.7^FTI=101.0-108.0]
# prune value of [T3=0.9-1.2^TSH=0.3-0.7^FTI=101.0-108.0]: 1
# prune value of [T3=0.9-1.2^TSH=0.3-0.7]: 1
# prune value of [T3=0.9-1.2]: 0.04
# pruned rule: [T3=0.9-1.2^TSH=0.3-0.7]
# updated ruleset: ...[[T3=<0.9^TSH=0.3-0.7] V [T3=0.9-1.2^TSH=0.3-0.7]]
#
# rule theory bits| [T3=0.9-1.2^TSH=0.3-0.7] k 2 n 111 pr 0.02: 8.2 bits
# exceptions_bits| [[T3=<0.9^TSH=<0.3^sex=F] V [T3=<0.9^TSH=1.1-1.7]]...:
#  N 2530 p 91 fp 8 fn 141: exceptions_bits 827
# rule dl: 8.2
# updated theory dl: 50.6
# exceptions: 827
# total dl: 877
# mdl 893 (diff -16.33 <= 64)
# examples remaining: 141 pos, 2298 neg
#
# pos_growset 94 pos_pruneset 47
# neg_growset 1539 neg_pruneset 759
# growing rule from initial rule: [True]
# gain 127 T3=0.9-1.2
# negs remaining: 59
# gain 8.6 FTI=108.0-115.0
# negs remaining: 3
# gain 2.2 sick=f
# negs remaining: 1
# gain 1.3 query_hypothyroid=f
# negs remaining: 0
# grew rule: [T3=0.9-1.2^FTI=108.0-115.0^sick=f^query_hypothyroid=f]
# prune value of [T3=0.9-1.2^FTI=108.0-115.0^sick=f^query_hypothyroid=f]: 1
# prune value of [T3=0.9-1.2^FTI=108.0-115.0^sick=f]: 1
# prune value of [T3=0.9-1.2^FTI=108.0-115.0]: 1
# prune value of [T3=0.9-1.2]: -0.33
# pruned rule: [T3=0.9-1.2^FTI=108.0-115.0]
# updated ruleset: ...[[T3=0.9-1.2^TSH=0.3-0.7] V [T3=0.9-1.2^FTI=108.0-115.0]]
#
# rule theory bits| [T3=0.9-1.2^FTI=108.0-115.0] k 2 n 111 pr 0.02: 8.2 bits
# exceptions_bits| [[T3=<0.9^TSH=<0.3^sex=F] V [T3=<0.9^TSH=1.1-1.7]]...:
#  N 2530 p 108 fp 11 fn 127: exceptions_bits 780
# rule dl: 8.2
# updated theory dl: 58.9
# exceptions: 780
# total dl: 839
# mdl 877 (diff -38.27 <= 64)
# examples remaining: 127 pos, 2295 neg
#
# pos_growset 85 pos_pruneset 42
# neg_growset 1537 neg_pruneset 758
# growing rule from initial rule: [True]
# gain 113 T3=<0.9
# negs remaining: 69
# gain 13 TSH=1.7-3.2
# negs remaining: 1
# gain 1.1 sick=f
# negs remaining: 0
# grew rule: [T3=<0.9^TSH=1.7-3.2^sick=f]
# prune value of [T3=<0.9^TSH=1.7-3.2^sick=f]: 1
# prune value of [T3=<0.9^TSH=1.7-3.2]: 1
# prune value of [T3=<0.9]: 0.16
# pruned rule: [T3=<0.9^TSH=1.7-3.2]
# updated ruleset: ...[[T3=0.9-1.2^FTI=108.0-115.0] V [T3=<0.9^TSH=1.7-3.2]]
#
# rule theory bits| [T3=<0.9^TSH=1.7-3.2] k 2 n 111 pr 0.02: 8.2 bits
# exceptions_bits| [[T3=<0.9^TSH=<0.3^sex=F] V [T3=<0.9^TSH=1.1-1.7]]...:
#  N 2530 p 124 fp 12 fn 112: exceptions_bits 721
# rule dl: 8.2
# updated theory dl: 67.1
# exceptions: 721
# total dl: 788
# mdl 839 (diff -51.11 <= 64)
# examples remaining: 112 pos, 2294 neg
#
# pos_growset 75 pos_pruneset 37
# neg_growset 1536 neg_pruneset 758
# growing rule from initial rule: [True]
# gain 97.4 T3=0.9-1.2
# negs remaining: 67
# gain 7.8 TSH=<0.3
# negs remaining: 22
# gain 3.4 TT4=<63.0
# negs remaining: 1
# gain 1.1 sick=f
# negs remaining: 0
# grew rule: [T3=0.9-1.2^TSH=<0.3^TT4=<63.0^sick=f]
# prune value of [T3=0.9-1.2^TSH=<0.3^TT4=<63.0^sick=f]: 0
# prune value of [T3=0.9-1.2^TSH=<0.3^TT4=<63.0]: 0
# prune value of [T3=0.9-1.2^TSH=<0.3]: 0.06
# prune value of [T3=0.9-1.2]: -0.29
# pruned rule: [T3=0.9-1.2^TSH=<0.3]
# updated ruleset: ...[[T3=<0.9^TSH=1.7-3.2] V [T3=0.9-1.2^TSH=<0.3]]
#
# rule theory bits| [T3=0.9-1.2^TSH=<0.3] k 2 n 111 pr 0.02: 8.2 bits
# exceptions_bits| [[T3=<0.9^TSH=<0.3^sex=F] V [T3=<0.9^TSH=1.1-1.7]]...:
#  N 2530 p 180 fp 42 fn 86: exceptions_bits 684
# rule dl: 8.2
# updated theory dl: 75.3
# exceptions: 684
# total dl: 759
# mdl 788 (diff -28.86 <= 64)
# examples remaining: 86 pos, 2264 neg
#
# pos_growset 57 pos_pruneset 29
# neg_growset 1516 neg_pruneset 748
# growing rule from initial rule: [True]
# gain 116 T3=<0.9
# negs remaining: 62
# gain 11.3 TSH=<0.3
# negs remaining: 4
# gain 1.2 age=70.0-76.0
# negs remaining: 0
# grew rule: [T3=<0.9^TSH=<0.3^age=70.0-76.0]
# prune value of [T3=<0.9^TSH=<0.3^age=70.0-76.0]: 1
# prune value of [T3=<0.9^TSH=<0.3]: 0.6
# prune value of [T3=<0.9]: -0.22
# pruned rule unchanged
# updated ruleset: ...[[T3=0.9-1.2^TSH=<0.3] V [T3=<0.9^TSH=<0.3^age=70.0-76.0]]
#
# rule theory bits| [T3=<0.9^TSH=<0.3^age=70.0-76.0] k 3 n 111 pr 0.03: 11.5 bits
# exceptions_bits| [[T3=<0.9^TSH=<0.3^sex=F] V [T3=<0.9^TSH=1.1-1.7]]...:
#  N 2530 p 183 fp 42 fn 83: exceptions_bits 670
# rule dl: 11.5
# updated theory dl: 86.8
# exceptions: 670
# total dl: 757
# mdl 759 (diff -1.67 <= 64)
# examples remaining: 83 pos, 2264 neg
#
# pos_growset 55 pos_pruneset 28
# neg_growset 1516 neg_pruneset 748
# growing rule from initial rule: [True]
# gain 104 T3=<0.9
# negs remaining: 56
# gain 11.9 FTI=71.0-86.0
# negs remaining: 1
# gain 0.96 query_hypothyroid=f
# negs remaining: 0
# grew rule: [T3=<0.9^FTI=71.0-86.0^query_hypothyroid=f]
# prune value of [T3=<0.9^FTI=71.0-86.0^query_hypothyroid=f]: 0.5
# prune value of [T3=<0.9^FTI=71.0-86.0]: 0.2
# prune value of [T3=<0.9]: -0.29
# pruned rule unchanged
# updated ruleset: ...[[T3=<0.9^TSH=<0.3^age=70.0-76.0] V [T3=<0.9^FTI=71.0-86.0^query_hypothyroid=f]]
#
# rule theory bits| [T3=<0.9^FTI=71.0-86.0^query_hypothyroid=f] k 3 n 111 pr 0.03: 11.5 bits
# exceptions_bits| [[T3=<0.9^TSH=<0.3^sex=F] V [T3=<0.9^TSH=1.1-1.7]]...:
#  N 2530 p 193 fp 43 fn 74: exceptions_bits 632
# rule dl: 11.5
# updated theory dl: 98.4
# exceptions: 632
# total dl: 730
# mdl 757 (diff -27.01 <= 64)
# examples remaining: 74 pos, 2263 neg
#
# pos_growset 49 pos_pruneset 25
# neg_growset 1516 neg_pruneset 747
# growing rule from initial rule: [True]
# gain 81.1 T3=<0.9
# negs remaining: 60
# gain 12.6 TSH=0.7-1.1
# negs remaining: 1
# gain 0.61 sex=F
# negs remaining: 0
# grew rule: [T3=<0.9^TSH=0.7-1.1^sex=F]
# prune value of [T3=<0.9^TSH=0.7-1.1^sex=F]: 0.33
# prune value of [T3=<0.9^TSH=0.7-1.1]: 0.33
# prune value of [T3=<0.9]: -0.3
# pruned rule: [T3=<0.9^TSH=0.7-1.1]
# updated ruleset: ...[[T3=<0.9^FTI=71.0-86.0^query_hypothyroid=f] V [T3=<0.9^TSH=0.7-1.1]]
#
# rule theory bits| [T3=<0.9^TSH=0.7-1.1] k 2 n 111 pr 0.02: 8.2 bits
# exceptions_bits| [[T3=<0.9^TSH=<0.3^sex=F] V [T3=<0.9^TSH=1.1-1.7]]...:
#  N 2530 p 207 fp 46 fn 63: exceptions_bits 586
# rule dl: 8.2
# updated theory dl: 107
# exceptions: 586
# total dl: 693
# mdl 730 (diff -37.24 <= 64)
# examples remaining: 63 pos, 2260 neg
#
# pos_growset 42 pos_pruneset 21
# neg_growset 1514 neg_pruneset 746
# growing rule from initial rule: [True]
# gain 61.4 T3=<0.9
# negs remaining: 57
# gain 15 TSH=3.2-9.67
# negs remaining: 4
# gain 1.3 sex=F
# negs remaining: 2
# gain 0.87 query_hypothyroid=t
# negs remaining: 0
# grew rule: [T3=<0.9^TSH=3.2-9.67^sex=F^query_hypothyroid=t]
# prune value of [T3=<0.9^TSH=3.2-9.67^sex=F^query_hypothyroid=t]: 1
# prune value of [T3=<0.9^TSH=3.2-9.67^sex=F]: 0.33
# prune value of [T3=<0.9^TSH=3.2-9.67]: 0.33
# prune value of [T3=<0.9]: -0.49
# pruned rule unchanged
# updated ruleset: ...[[T3=<0.9^TSH=0.7-1.1] V [T3=<0.9^TSH=3.2-9.67^sex=F^query_hypothyroid=t]]
#
# rule theory bits| [T3=<0.9^TSH=3.2-9.67^sex=F^query_hypothyroid=t] k 4 n 111 pr 0.04: 14.4 bits
# exceptions_bits| [[T3=<0.9^TSH=<0.3^sex=F] V [T3=<0.9^TSH=1.1-1.7]]...:
#  N 2530 p 210 fp 46 fn 60: exceptions_bits 572
# rule dl: 14.4
# updated theory dl: 121
# exceptions: 572
# total dl: 693
# mdl 693 (diff -0.16 <= 64)
# examples remaining: 60 pos, 2260 neg
#
# pos_growset 40 pos_pruneset 20
# neg_growset 1514 neg_pruneset 746
# growing rule from initial rule: [True]
# gain 48.8 T3=<0.9
# negs remaining: 61
# gain 15.4 TSH=<0.3
# negs remaining: 4
# gain 2 query_on_thyroxine=f
# negs remaining: 2
# gain 1.6 T4U=<0.75
# negs remaining: 0
# grew rule: [T3=<0.9^TSH=<0.3^query_on_thyroxine=f^T4U=<0.75]
# prune value of [T3=<0.9^TSH=<0.3^query_on_thyroxine=f^T4U=<0.75]: 1
# prune value of [T3=<0.9^TSH=<0.3^query_on_thyroxine=f]: 0.33
# prune value of [T3=<0.9^TSH=<0.3]: 0.33
# prune value of [T3=<0.9]: -0.42
# pruned rule unchanged
# updated ruleset: ...[[T3=<0.9^TSH=3.2-9.67^sex=F^query_hypothyroid=t] V [T3=<0.9^TSH=<0.3^query_on_thyroxine=f^T4U=<0.75]]
#
# rule theory bits| [T3=<0.9^TSH=<0.3^query_on_thyroxine=f^T4U=<0.75] k 4 n 111 pr 0.04: 14.4 bits
# exceptions_bits| [[T3=<0.9^TSH=<0.3^sex=F] V [T3=<0.9^TSH=1.1-1.7]]...:
#  N 2530 p 216 fp 46 fn 54: exceptions_bits 542
# rule dl: 14.4
# updated theory dl: 135
# exceptions: 542
# total dl: 677
# mdl 693 (diff -15.44 <= 64)
# examples remaining: 54 pos, 2260 neg
#
# pos_growset 36 pos_pruneset 18
# neg_growset 1514 neg_pruneset 746
# growing rule from initial rule: [True]
# gain 47.8 T3=0.9-1.2
# negs remaining: 44
# gain 5.2 FTI=123.0-137.0
# negs remaining: 3
# gain 1.4 TSH=3.2-9.67
# negs remaining: 0
# grew rule: [T3=0.9-1.2^FTI=123.0-137.0^TSH=3.2-9.67]
# prune value of [T3=0.9-1.2^FTI=123.0-137.0^TSH=3.2-9.67]: 1
# prune value of [T3=0.9-1.2^FTI=123.0-137.0]: 0.33
# prune value of [T3=0.9-1.2]: -0.38
# pruned rule unchanged
# updated ruleset: ...[[T3=<0.9^TSH=<0.3^query_on_thyroxine=f^T4U=<0.75] V [T3=0.9-1.2^FTI=123.0-137.0^TSH=3.2-9.67]]
#
# rule theory bits| [T3=0.9-1.2^FTI=123.0-137.0^TSH=3.2-9.67] k 3 n 111 pr 0.03: 11.5 bits
# exceptions_bits| [[T3=<0.9^TSH=<0.3^sex=F] V [T3=<0.9^TSH=1.1-1.7]]...:
#  N 2530 p 218 fp 46 fn 52: exceptions_bits 532
# rule dl: 11.5
# updated theory dl: 147
# exceptions: 532
# total dl: 679
# mdl 677 (diff 1.4 <= 64)
# examples remaining: 52 pos, 2260 neg
#
# pos_growset 34 pos_pruneset 18
# neg_growset 1514 neg_pruneset 746
# growing rule from initial rule: [True]
# gain 45.1 T3=0.9-1.2
# negs remaining: 42
# gain 6.6 TSH=1.7-3.2
# negs remaining: 6
# gain 2.7 TT4=122.0-136.0
# negs remaining: 0
# grew rule: [T3=0.9-1.2^TSH=1.7-3.2^TT4=122.0-136.0]
# prune value of [T3=0.9-1.2^TSH=1.7-3.2^TT4=122.0-136.0]: 1
# prune value of [T3=0.9-1.2^TSH=1.7-3.2]: -0.2
# prune value of [T3=0.9-1.2]: -0.47
# pruned rule unchanged
# updated ruleset: ...[[T3=0.9-1.2^FTI=123.0-137.0^TSH=3.2-9.67] V [T3=0.9-1.2^TSH=1.7-3.2^TT4=122.0-136.0]]
#
# rule theory bits| [T3=0.9-1.2^TSH=1.7-3.2^TT4=122.0-136.0] k 3 n 111 pr 0.03: 11.5 bits
# exceptions_bits| [[T3=<0.9^TSH=<0.3^sex=F] V [T3=<0.9^TSH=1.1-1.7]]...:
#  N 2530 p 221 fp 46 fn 49: exceptions_bits 516
# rule dl: 11.5
# updated theory dl: 159
# exceptions: 516
# total dl: 675
# mdl 677 (diff -2.58 <= 64)
# examples remaining: 49 pos, 2260 neg
#
# pos_growset 32 pos_pruneset 17
# neg_growset 1514 neg_pruneset 746
# growing rule from initial rule: [True]
# gain 35.3 T3=<0.9
# negs remaining: 49
# gain 7.4 TSH=3.2-9.67
# negs remaining: 5
# gain 1.7 age=>76.0
# negs remaining: 1
# gain 0.32 sex=M
# negs remaining: 0
# grew rule: [T3=<0.9^TSH=3.2-9.67^age=>76.0^sex=M]
# prune value of [T3=<0.9^TSH=3.2-9.67^age=>76.0^sex=M]: 1
# prune value of [T3=<0.9^TSH=3.2-9.67^age=>76.0]: 1
# prune value of [T3=<0.9^TSH=3.2-9.67]: 0.71
# prune value of [T3=<0.9]: -0.62
# pruned rule: [T3=<0.9^TSH=3.2-9.67^age=>76.0]
# updated ruleset: ...[[T3=0.9-1.2^TSH=1.7-3.2^TT4=122.0-136.0] V [T3=<0.9^TSH=3.2-9.67^age=>76.0]]
#
# rule theory bits| [T3=<0.9^TSH=3.2-9.67^age=>76.0] k 3 n 111 pr 0.03: 11.5 bits
# exceptions_bits| [[T3=<0.9^TSH=<0.3^sex=F] V [T3=<0.9^TSH=1.1-1.7]]...:
#  N 2530 p 225 fp 47 fn 46: exceptions_bits 503
# rule dl: 11.5
# updated theory dl: 170
# exceptions: 503
# total dl: 673
# mdl 675 (diff -1.98 <= 64)
# examples remaining: 46 pos, 2259 neg
#
# pos_growset 30 pos_pruneset 16
# neg_growset 1513 neg_pruneset 746
# growing rule from initial rule: [True]
# gain 38.3 T3=<0.9
# negs remaining: 58
# gain 10.2 TSH=3.2-9.67
# negs remaining: 2
# gain 1.2 sex=F
# negs remaining: 0
# grew rule: [T3=<0.9^TSH=3.2-9.67^sex=F]
# prune value of [T3=<0.9^TSH=3.2-9.67^sex=F]: 0
# prune value of [T3=<0.9^TSH=3.2-9.67]: 0
# prune value of [T3=<0.9]: -0.71
# pruned rule: [T3=<0.9^TSH=3.2-9.67]
# updated ruleset: ...[[T3=<0.9^TSH=3.2-9.67^age=>76.0] V [T3=<0.9^TSH=3.2-9.67]]
#
# rule theory bits| [T3=<0.9^TSH=3.2-9.67] k 2 n 111 pr 0.02: 8.2 bits
# exceptions_bits| [[T3=<0.9^TSH=<0.3^sex=F] V [T3=<0.9^TSH=1.1-1.7]]...:
#  N 2530 p 237 fp 52 fn 39: exceptions_bits 476
# rule dl: 8.2
# updated theory dl: 178
# exceptions: 476
# total dl: 654
# mdl 673 (diff -18.55 <= 64)
# examples remaining: 39 pos, 2254 neg
#
# pos_growset 26 pos_pruneset 13
# neg_growset 1510 neg_pruneset 744
# growing rule from initial rule: [True]
# gain 49.1 T3=0.9-1.2
# negs remaining: 44
# gain 6.6 TT4=63.0-78.0
# negs remaining: 4
# gain 2.2 T4U=0.75-0.83
# negs remaining: 0
# grew rule: [T3=0.9-1.2^TT4=63.0-78.0^T4U=0.75-0.83]
# prune value of [T3=0.9-1.2^TT4=63.0-78.0^T4U=0.75-0.83]: 1
# prune value of [T3=0.9-1.2^TT4=63.0-78.0]: 0
# prune value of [T3=0.9-1.2]: -0.6
# pruned rule unchanged
# updated ruleset: ...[[T3=<0.9^TSH=3.2-9.67] V [T3=0.9-1.2^TT4=63.0-78.0^T4U=0.75-0.83]]
#
# rule theory bits| [T3=0.9-1.2^TT4=63.0-78.0^T4U=0.75-0.83] k 3 n 111 pr 0.03: 11.5 bits
# exceptions_bits| [[T3=<0.9^TSH=<0.3^sex=F] V [T3=<0.9^TSH=1.1-1.7]]...:
#  N 2530 p 240 fp 52 fn 36: exceptions_bits 459
# rule dl: 11.5
# updated theory dl: 190
# exceptions: 459
# total dl: 649
# mdl 654 (diff -5.13 <= 64)
# examples remaining: 36 pos, 2254 neg
#
# pos_growset 24 pos_pruneset 12
# neg_growset 1510 neg_pruneset 744
# growing rule from initial rule: [True]
# gain 23.7 T3=0.9-1.2
# negs remaining: 39
# gain 5.1 TT4=87.0-96.0
# negs remaining: 0
# grew rule: [T3=0.9-1.2^TT4=87.0-96.0]
# prune value of [T3=0.9-1.2^TT4=87.0-96.0]: -0.33
# prune value of [T3=0.9-1.2]: -0.52
# pruned rule unchanged
# updated ruleset: ...[[T3=0.9-1.2^TT4=63.0-78.0^T4U=0.75-0.83] V [T3=0.9-1.2^TT4=87.0-96.0]]
#
# rule theory bits| [T3=0.9-1.2^TT4=87.0-96.0] k 2 n 111 pr 0.02: 8.2 bits
# exceptions_bits| [[T3=<0.9^TSH=<0.3^sex=F] V [T3=<0.9^TSH=1.1-1.7]]...:
#  N 2530 p 247 fp 56 fn 33: exceptions_bits 451
# rule dl: 8.2
# updated theory dl: 198
# exceptions: 451
# total dl: 649
# mdl 649 (diff -0.18 <= 64)
# examples remaining: 33 pos, 2250 neg
#
# pos_growset 22 pos_pruneset 11
# neg_growset 1507 neg_pruneset 743
# growing rule from initial rule: [True]
# gain 26 T3=<0.9
# negs remaining: 54
# gain 8.5 TSH=<0.3
# negs remaining: 3
# gain 1.4 TT4=104.0-112.0
# negs remaining: 0
# grew rule: [T3=<0.9^TSH=<0.3^TT4=104.0-112.0]
# prune value of [T3=<0.9^TSH=<0.3^TT4=104.0-112.0]: 1
# prune value of [T3=<0.9^TSH=<0.3]: -0.33
# prune value of [T3=<0.9]: -0.92
# pruned rule unchanged
# updated ruleset: ...[[T3=0.9-1.2^TT4=87.0-96.0] V [T3=<0.9^TSH=<0.3^TT4=104.0-112.0]]
#
# rule theory bits| [T3=<0.9^TSH=<0.3^TT4=104.0-112.0] k 3 n 111 pr 0.03: 11.5 bits
# exceptions_bits| [[T3=<0.9^TSH=<0.3^sex=F] V [T3=<0.9^TSH=1.1-1.7]]...:
#  N 2530 p 249 fp 56 fn 31: exceptions_bits 439
# rule dl: 11.5
# updated theory dl: 210
# exceptions: 439
# total dl: 649
# mdl 649 (diff 0.01 <= 64)
# examples remaining: 31 pos, 2250 neg
#
# pos_growset 20 pos_pruneset 11
# neg_growset 1507 neg_pruneset 743
# growing rule from initial rule: [True]
# gain 20.8 T3=0.9-1.2
# negs remaining: 39
# gain 4 TT4=96.0-104.0
# negs remaining: 2
# gain 0.74 age=>76.0
# negs remaining: 0
# grew rule: [T3=0.9-1.2^TT4=96.0-104.0^age=>76.0]
# prune value of [T3=0.9-1.2^TT4=96.0-104.0^age=>76.0]: 0
# prune value of [T3=0.9-1.2^TT4=96.0-104.0]: 0.2
# prune value of [T3=0.9-1.2]: -0.56
# pruned rule: [T3=0.9-1.2^TT4=96.0-104.0]
# updated ruleset: ...[[T3=<0.9^TSH=<0.3^TT4=104.0-112.0] V [T3=0.9-1.2^TT4=96.0-104.0]]
#
# rule theory bits| [T3=0.9-1.2^TT4=96.0-104.0] k 2 n 111 pr 0.02: 8.2 bits
# exceptions_bits| [[T3=<0.9^TSH=<0.3^sex=F] V [T3=<0.9^TSH=1.1-1.7]]...:
#  N 2530 p 257 fp 60 fn 27: exceptions_bits 424
# rule dl: 8.2
# updated theory dl: 218
# exceptions: 424
# total dl: 642
# mdl 649 (diff -6.92 <= 64)
# examples remaining: 27 pos, 2246 neg
#
# pos_growset 18 pos_pruneset 9
# neg_growset 1504 neg_pruneset 742
# growing rule from initial rule: [True]
# gain 18.8 FTI=>165.0
# negs remaining: 133
# gain 5.2 T4U=0.88-0.92
# negs remaining: 15
# gain 3.2 TT4=136.0-162.0
# negs remaining: 5
# gain 1.8 on_thyroxine=f
# negs remaining: 2
# gain 0.79 T3_measured=y
# negs remaining: 1
# gain 0.32 age=31.0-38.0
# negs remaining: 0
# grew rule: [FTI=>165.0^T4U=0.88-0.92^TT4=136.0-162.0^on_thyroxine=f^T3_measured=y^age=31.0-38.0]
# prune value of [FTI=>165.0^T4U=0.88-0.92^TT4=136.0-162.0^on_thyroxine=f^T3_measured=y^age=31.0-38.0]: 1
# prune value of [FTI=>165.0^T4U=0.88-0.92^TT4=136.0-162.0^on_thyroxine=f^T3_measured=y]: -0.33
# prune value of [FTI=>165.0^T4U=0.88-0.92^TT4=136.0-162.0^on_thyroxine=f]: -0.33
# prune value of [FTI=>165.0^T4U=0.88-0.92^TT4=136.0-162.0]: -0.5
# prune value of [FTI=>165.0^T4U=0.88-0.92]: -0.8
# prune value of [FTI=>165.0]: -0.97
# pruned rule unchanged
# updated ruleset: ...[[T3=0.9-1.2^TT4=96.0-104.0] V [FTI=>165.0^T4U=0.88-0.92^TT4=136.0-162.0^on_thyroxine=f^T3_measured=y^age=31.0-38.0]]
#
# rule theory bits| [FTI=>165.0^T4U=0.88-0.92^TT4=136.0-162.0^on_thyroxine=f^T3_measured=y^age=31.0-38.0] k 6 n 111 pr 0.05: 19.4 bits
# exceptions_bits| [[T3=<0.9^TSH=<0.3^sex=F] V [T3=<0.9^TSH=1.1-1.7]]...:
#  N 2530 p 258 fp 60 fn 26: exceptions_bits 418
# rule dl: 19.4
# updated theory dl: 237
# exceptions: 418
# total dl: 655
# mdl 642 (diff 13.4 <= 64)
# examples remaining: 26 pos, 2246 neg
#
# pos_growset 17 pos_pruneset 9
# neg_growset 1504 neg_pruneset 742
# growing rule from initial rule: [True]
# gain 18 T3=0.9-1.2
# negs remaining: 36
# gain 3.7 sex=M
# negs remaining: 8
# gain 1.7 TT4=78.0-87.0
# negs remaining: 2
# gain 1.5 FTI=86.0-94.0
# negs remaining: 0
# grew rule: [T3=0.9-1.2^sex=M^TT4=78.0-87.0^FTI=86.0-94.0]
# prune value of [T3=0.9-1.2^sex=M^TT4=78.0-87.0^FTI=86.0-94.0]: 0
# prune value of [T3=0.9-1.2^sex=M^TT4=78.0-87.0]: -0.33
# prune value of [T3=0.9-1.2^sex=M]: -0.5
# prune value of [T3=0.9-1.2]: -0.74
# pruned rule unchanged
# updated ruleset: ...[[FTI=>165.0^T4U=0.88-0.92^TT4=136.0-162.0^on_thyroxine=f^T3_measured=y^age=31.0-38.0] V [T3=0.9-1.2^sex=M^TT4=78.0-87.0^FTI=86.0-94.0]]
#
# rule theory bits| [T3=0.9-1.2^sex=M^TT4=78.0-87.0^FTI=86.0-94.0] k 4 n 111 pr 0.04: 14.4 bits
# exceptions_bits| [[T3=<0.9^TSH=<0.3^sex=F] V [T3=<0.9^TSH=1.1-1.7]]...:
#  N 2530 p 261 fp 61 fn 24: exceptions_bits 408
# rule dl: 14.4
# updated theory dl: 252
# exceptions: 408
# total dl: 660
# mdl 642 (diff 17.7 <= 64)
# examples remaining: 24 pos, 2245 neg
#
# pos_growset 16 pos_pruneset 8
# neg_growset 1504 neg_pruneset 741
# growing rule from initial rule: [True]
# gain 16.8 FTI=>165.0
# negs remaining: 127
# gain 4.7 age=<24.0
# negs remaining: 7
# gain 1.7 T3=1.8-2.0
# negs remaining: 0
# grew rule: [FTI=>165.0^age=<24.0^T3=1.8-2.0]
# prune value of [FTI=>165.0^age=<24.0^T3=1.8-2.0]: 0
# prune value of [FTI=>165.0^age=<24.0]: -0.67
# prune value of [FTI=>165.0]: -0.97
# pruned rule unchanged
# updated ruleset: ...[[T3=0.9-1.2^sex=M^TT4=78.0-87.0^FTI=86.0-94.0] V [FTI=>165.0^age=<24.0^T3=1.8-2.0]]
#
# rule theory bits| [FTI=>165.0^age=<24.0^T3=1.8-2.0] k 3 n 111 pr 0.03: 11.5 bits
# exceptions_bits| [[T3=<0.9^TSH=<0.3^sex=F] V [T3=<0.9^TSH=1.1-1.7]]...:
#  N 2530 p 263 fp 62 fn 23: exceptions_bits 404
# rule dl: 11.5
# updated theory dl: 263
# exceptions: 404
# total dl: 667
# mdl 642 (diff 25.2 <= 64)
# examples remaining: 23 pos, 2244 neg
#
# pos_growset 15 pos_pruneset 8
# neg_growset 1503 neg_pruneset 741
# growing rule from initial rule: [True]
# gain 10.1 T4U=0.88-0.92
# negs remaining: 134
# gain 8.5 age=>76.0
# negs remaining: 9
# gain 2.6 TT4=63.0-78.0
# negs remaining: 1
# gain 0.42 query_hypothyroid=f
# negs remaining: 0
# grew rule: [T4U=0.88-0.92^age=>76.0^TT4=63.0-78.0^query_hypothyroid=f]
# prune value of [T4U=0.88-0.92^age=>76.0^TT4=63.0-78.0^query_hypothyroid=f]: 0
# prune value of [T4U=0.88-0.92^age=>76.0^TT4=63.0-78.0]: 0
# prune value of [T4U=0.88-0.92^age=>76.0]: -0.71
# prune value of [T4U=0.88-0.92]: -0.9
# pruned rule: [T4U=0.88-0.92^age=>76.0^TT4=63.0-78.0]
# updated ruleset: ...[[FTI=>165.0^age=<24.0^T3=1.8-2.0] V [T4U=0.88-0.92^age=>76.0^TT4=63.0-78.0]]
#
# rule theory bits| [T4U=0.88-0.92^age=>76.0^TT4=63.0-78.0] k 3 n 111 pr 0.03: 11.5 bits
# exceptions_bits| [[T3=<0.9^TSH=<0.3^sex=F] V [T3=<0.9^TSH=1.1-1.7]]...:
#  N 2530 p 267 fp 64 fn 21: exceptions_bits 396
# rule dl: 11.5
# updated theory dl: 275
# exceptions: 396
# total dl: 670
# mdl 642 (diff 28.3 <= 64)
# examples remaining: 21 pos, 2242 neg
#
# pos_growset 14 pos_pruneset 7
# neg_growset 1502 neg_pruneset 740
# growing rule from initial rule: [True]
# gain 12.8 T3=<0.9
# negs remaining: 50
# gain 7.4 on_thyroxine=t
# negs remaining: 4
# gain 2 TT4=112.0-122.0
# negs remaining: 0
# grew rule: [T3=<0.9^on_thyroxine=t^TT4=112.0-122.0]
# prune value of [T3=<0.9^on_thyroxine=t^TT4=112.0-122.0]: 1
# prune value of [T3=<0.9^on_thyroxine=t]: 0
# prune value of [T3=<0.9]: -0.86
# pruned rule unchanged
# updated ruleset: ...[[T4U=0.88-0.92^age=>76.0^TT4=63.0-78.0] V [T3=<0.9^on_thyroxine=t^TT4=112.0-122.0]]
#
# rule theory bits| [T3=<0.9^on_thyroxine=t^TT4=112.0-122.0] k 3 n 111 pr 0.03: 11.5 bits
# exceptions_bits| [[T3=<0.9^TSH=<0.3^sex=F] V [T3=<0.9^TSH=1.1-1.7]]...:
#  N 2530 p 269 fp 64 fn 19: exceptions_bits 383
# rule dl: 11.5
# updated theory dl: 286
# exceptions: 383
# total dl: 669
# mdl 642 (diff 27.1 <= 64)
# examples remaining: 19 pos, 2242 neg
#
# pos_growset 12 pos_pruneset 7
# neg_growset 1502 neg_pruneset 740
# growing rule from initial rule: [True]
# gain 11.8 FTI=>165.0
# negs remaining: 130
# gain 4.5 tumor=t
# negs remaining: 0
# grew rule: [FTI=>165.0^tumor=t]
# prune value of [FTI=>165.0^tumor=t]: 1
# prune value of [FTI=>165.0]: -0.95
# pruned rule unchanged
# updated ruleset: ...[[T3=<0.9^on_thyroxine=t^TT4=112.0-122.0] V [FTI=>165.0^tumor=t]]
#
# rule theory bits| [FTI=>165.0^tumor=t] k 2 n 111 pr 0.02: 8.2 bits
# exceptions_bits| [[T3=<0.9^TSH=<0.3^sex=F] V [T3=<0.9^TSH=1.1-1.7]]...:
#  N 2530 p 270 fp 64 fn 18: exceptions_bits 376
# rule dl: 8.2
# updated theory dl: 294
# exceptions: 376
# total dl: 671
# mdl 642 (diff 28.8 <= 64)
# examples remaining: 18 pos, 2242 neg
#
# pos_growset 12 pos_pruneset 6
# neg_growset 1502 neg_pruneset 740
# growing rule from initial rule: [True]
# gain 11.8 TT4=<63.0
# negs remaining: 130
# gain 14 TSH=0.7-1.1
# negs remaining: 5
# gain 1.3 FTI=<71.0
# negs remaining: 3
# gain 1.1 sex=M
# negs remaining: 1
# gain 0.32 age=70.0-76.0
# negs remaining: 0
# grew rule: [TT4=<63.0^TSH=0.7-1.1^FTI=<71.0^sex=M^age=70.0-76.0]
# prune value of [TT4=<63.0^TSH=0.7-1.1^FTI=<71.0^sex=M^age=70.0-76.0]: 1
# prune value of [TT4=<63.0^TSH=0.7-1.1^FTI=<71.0^sex=M]: 1
# prune value of [TT4=<63.0^TSH=0.7-1.1^FTI=<71.0]: 0
# prune value of [TT4=<63.0^TSH=0.7-1.1]: -0.33
# prune value of [TT4=<63.0]: -0.94
# pruned rule: [TT4=<63.0^TSH=0.7-1.1^FTI=<71.0^sex=M]
# updated ruleset: ...[[FTI=>165.0^tumor=t] V [TT4=<63.0^TSH=0.7-1.1^FTI=<71.0^sex=M]]
#
# rule theory bits| [TT4=<63.0^TSH=0.7-1.1^FTI=<71.0^sex=M] k 4 n 111 pr 0.04: 14.4 bits
# exceptions_bits| [[T3=<0.9^TSH=<0.3^sex=F] V [T3=<0.9^TSH=1.1-1.7]]...:
#  N 2530 p 274 fp 65 fn 15: exceptions_bits 358
# rule dl: 14.4
# updated theory dl: 309
# exceptions: 358
# total dl: 667
# mdl 642 (diff 25.3 <= 64)
# examples remaining: 15 pos, 2241 neg
#
# pos_growset 10 pos_pruneset 5
# neg_growset 1501 neg_pruneset 740
# growing rule from initial rule: [True]
# gain 9.7 TSH=<0.3
# negs remaining: 525
# gain 9.3 T3=<0.9
# negs remaining: 4
# gain 1.2 age=54.0-59.0
# negs remaining: 0
# grew rule: [TSH=<0.3^T3=<0.9^age=54.0-59.0]
# prune value of [TSH=<0.3^T3=<0.9^age=54.0-59.0]: 1
# prune value of [TSH=<0.3^T3=<0.9]: 0
# prune value of [TSH=<0.3]: -0.98
# pruned rule unchanged
# updated ruleset: ...[[TT4=<63.0^TSH=0.7-1.1^FTI=<71.0^sex=M] V [TSH=<0.3^T3=<0.9^age=54.0-59.0]]
#
# rule theory bits| [TSH=<0.3^T3=<0.9^age=54.0-59.0] k 3 n 111 pr 0.03: 11.5 bits
# exceptions_bits| [[T3=<0.9^TSH=<0.3^sex=F] V [T3=<0.9^TSH=1.1-1.7]]...:
#  N 2530 p 275 fp 65 fn 14: exceptions_bits 352
# rule dl: 11.5
# updated theory dl: 320
# exceptions: 352
# total dl: 672
# mdl 642 (diff 30 <= 64)
# examples remaining: 14 pos, 2241 neg
#
# pos_growset 9 pos_pruneset 5
# neg_growset 1501 neg_pruneset 740
# growing rule from initial rule: [True]
# gain 9.2 FTI=>165.0
# negs remaining: 149
# gain 5.4 T3=2.2-2.5
# negs remaining: 11
# gain 2.2 age=>76.0
# negs remaining: 0
# grew rule: [FTI=>165.0^T3=2.2-2.5^age=>76.0]
# prune value of [FTI=>165.0^T3=2.2-2.5^age=>76.0]: 1
# prune value of [FTI=>165.0^T3=2.2-2.5]: -0.5
# prune value of [FTI=>165.0]: -0.93
# pruned rule unchanged
# updated ruleset: ...[[TSH=<0.3^T3=<0.9^age=54.0-59.0] V [FTI=>165.0^T3=2.2-2.5^age=>76.0]]
#
# rule theory bits| [FTI=>165.0^T3=2.2-2.5^age=>76.0] k 3 n 111 pr 0.03: 11.5 bits
# exceptions_bits| [[T3=<0.9^TSH=<0.3^sex=F] V [T3=<0.9^TSH=1.1-1.7]]...:
#  N 2530 p 276 fp 65 fn 13: exceptions_bits 345
# rule dl: 11.5
# updated theory dl: 332
# exceptions: 345
# total dl: 677
# mdl 642 (diff 34.6 <= 64)
# examples remaining: 13 pos, 2241 neg
#
# pos_growset 8 pos_pruneset 5
# neg_growset 1501 neg_pruneset 740
# growing rule from initial rule: [True]
# gain 7.3 TT4=78.0-87.0
# negs remaining: 119
# gain 3.9 T3=<0.9
# negs remaining: 2
# gain 1 age=24.0-31.0
# negs remaining: 0
# grew rule: [TT4=78.0-87.0^T3=<0.9^age=24.0-31.0]
# prune value of [TT4=78.0-87.0^T3=<0.9^age=24.0-31.0]: 1
# prune value of [TT4=78.0-87.0^T3=<0.9]: 0
# prune value of [TT4=78.0-87.0]: -0.97
# pruned rule unchanged
# updated ruleset: ...[[FTI=>165.0^T3=2.2-2.5^age=>76.0] V [TT4=78.0-87.0^T3=<0.9^age=24.0-31.0]]
#
# rule theory bits| [TT4=78.0-87.0^T3=<0.9^age=24.0-31.0] k 3 n 111 pr 0.03: 11.5 bits
# exceptions_bits| [[T3=<0.9^TSH=<0.3^sex=F] V [T3=<0.9^TSH=1.1-1.7]]...:
#  N 2530 p 277 fp 65 fn 12: exceptions_bits 338
# rule dl: 11.5
# updated theory dl: 343
# exceptions: 338
# total dl: 681
# mdl 642 (diff 39 <= 64)
# examples remaining: 12 pos, 2241 neg
#
# pos_growset 8 pos_pruneset 4
# neg_growset 1501 neg_pruneset 740
# growing rule from initial rule: [True]
# gain 7.5 T3=0.9-1.2
# negs remaining: 34
# gain 3.6 FTI=115.0-123.0
# negs remaining: 0
# grew rule: [T3=0.9-1.2^FTI=115.0-123.0]
# prune value of [T3=0.9-1.2^FTI=115.0-123.0]: 1
# prune value of [T3=0.9-1.2]: -0.83
# pruned rule unchanged
# updated ruleset: ...[[TT4=78.0-87.0^T3=<0.9^age=24.0-31.0] V [T3=0.9-1.2^FTI=115.0-123.0]]
#
# rule theory bits| [T3=0.9-1.2^FTI=115.0-123.0] k 2 n 111 pr 0.02: 8.2 bits
# exceptions_bits| [[T3=<0.9^TSH=<0.3^sex=F] V [T3=<0.9^TSH=1.1-1.7]]...:
#  N 2530 p 278 fp 65 fn 11: exceptions_bits 330
# rule dl: 8.2
# updated theory dl: 352
# exceptions: 330
# total dl: 682
# mdl 642 (diff 40.1 <= 64)
# examples remaining: 11 pos, 2241 neg
#
# pos_growset 7 pos_pruneset 4
# neg_growset 1501 neg_pruneset 740
# growing rule from initial rule: [True]
# gain 8 T3=0.9-1.2
# negs remaining: 32
# gain 2.5 T4U=0.96-1.0
# negs remaining: 2
# gain 1 age=54.0-59.0
# negs remaining: 0
# grew rule: [T3=0.9-1.2^T4U=0.96-1.0^age=54.0-59.0]
# prune value of [T3=0.9-1.2^T4U=0.96-1.0^age=54.0-59.0]: 1
# prune value of [T3=0.9-1.2^T4U=0.96-1.0]: -0.5
# prune value of [T3=0.9-1.2]: -0.92
# pruned rule unchanged
# updated ruleset: ...[[T3=0.9-1.2^FTI=115.0-123.0] V [T3=0.9-1.2^T4U=0.96-1.0^age=54.0-59.0]]
#
# rule theory bits| [T3=0.9-1.2^T4U=0.96-1.0^age=54.0-59.0] k 3 n 111 pr 0.03: 11.5 bits
# exceptions_bits| [[T3=<0.9^TSH=<0.3^sex=F] V [T3=<0.9^TSH=1.1-1.7]]...:
#  N 2530 p 279 fp 65 fn 10: exceptions_bits 323
# rule dl: 11.5
# updated theory dl: 363
# exceptions: 323
# total dl: 686
# mdl 642 (diff 44.4 <= 64)
# examples remaining: 10 pos, 2241 neg
#
# pos_growset 6 pos_pruneset 4
# neg_growset 1501 neg_pruneset 740
# growing rule from initial rule: [True]
# gain 8.2 TT4=<63.0
# negs remaining: 127
# gain 5.2 TSH=<0.3
# negs remaining: 13
# gain 2.4 sick=t
# negs remaining: 0
# grew rule: [TT4=<63.0^TSH=<0.3^sick=t]
# prune value of [TT4=<63.0^TSH=<0.3^sick=t]: 1
# prune value of [TT4=<63.0^TSH=<0.3]: -0.6
# prune value of [TT4=<63.0]: -0.97
# pruned rule unchanged
# updated ruleset: ...[[T3=0.9-1.2^T4U=0.96-1.0^age=54.0-59.0] V [TT4=<63.0^TSH=<0.3^sick=t]]
#
# rule theory bits| [TT4=<63.0^TSH=<0.3^sick=t] k 3 n 111 pr 0.03: 11.5 bits
# exceptions_bits| [[T3=<0.9^TSH=<0.3^sex=F] V [T3=<0.9^TSH=1.1-1.7]]...:
#  N 2530 p 280 fp 65 fn 9: exceptions_bits 316
# rule dl: 11.5
# updated theory dl: 375
# exceptions: 316
# total dl: 690
# mdl 642 (diff 48.5 <= 64)
# examples remaining: 9 pos, 2241 neg
#
# pos_growset 6 pos_pruneset 3
# neg_growset 1501 neg_pruneset 740
# growing rule from initial rule: [True]
# gain 4.7 T4U=1.0-1.04
# negs remaining: 124
# gain 4.8 on_antithyroid_medication=t
# negs remaining: 1
# gain 0.58 sex=M
# negs remaining: 0
# grew rule: [T4U=1.0-1.04^on_antithyroid_medication=t^sex=M]
# prune value of [T4U=1.0-1.04^on_antithyroid_medication=t^sex=M]: 1
# prune value of [T4U=1.0-1.04^on_antithyroid_medication=t]: -0.5
# prune value of [T4U=1.0-1.04]: -0.97
# pruned rule unchanged
# updated ruleset: ...[[TT4=<63.0^TSH=<0.3^sick=t] V [T4U=1.0-1.04^on_antithyroid_medication=t^sex=M]]
#
# rule theory bits| [T4U=1.0-1.04^on_antithyroid_medication=t^sex=M] k 3 n 111 pr 0.03: 11.5 bits
# exceptions_bits| [[T3=<0.9^TSH=<0.3^sex=F] V [T3=<0.9^TSH=1.1-1.7]]...:
#  N 2530 p 281 fp 65 fn 8: exceptions_bits 308
# rule dl: 11.5
# updated theory dl: 386
# exceptions: 308
# total dl: 694
# mdl 642 (diff 52.4 <= 64)
# examples remaining: 8 pos, 2241 neg
#
# pos_growset 5 pos_pruneset 3
# neg_growset 1501 neg_pruneset 740
# growing rule from initial rule: [True]
# gain 5 TSH=<0.3
# negs remaining: 524
# gain 4.9 sick=t
# negs remaining: 5
# gain 1.8 T4U=1.1-1.22
# negs remaining: 0
# grew rule: [TSH=<0.3^sick=t^T4U=1.1-1.22]
# prune value of [TSH=<0.3^sick=t^T4U=1.1-1.22]: 1
# prune value of [TSH=<0.3^sick=t]: 0
# prune value of [TSH=<0.3]: -0.97
# pruned rule unchanged
# updated ruleset: ...[[T4U=1.0-1.04^on_antithyroid_medication=t^sex=M] V [TSH=<0.3^sick=t^T4U=1.1-1.22]]
#
# rule theory bits| [TSH=<0.3^sick=t^T4U=1.1-1.22] k 3 n 111 pr 0.03: 11.5 bits
# exceptions_bits| [[T3=<0.9^TSH=<0.3^sex=F] V [T3=<0.9^TSH=1.1-1.7]]...:
#  N 2530 p 282 fp 65 fn 7: exceptions_bits 300
# rule dl: 11.5
# updated theory dl: 398
# exceptions: 300
# total dl: 698
# mdl 642 (diff 56.2 <= 64)
# examples remaining: 7 pos, 2241 neg
#
# pos_growset 4 pos_pruneset 3
# neg_growset 1501 neg_pruneset 740
# growing rule from initial rule: [True]
# gain 6.1 TSH=<0.3
# negs remaining: 516
# gain 4.9 T3=<0.9
# negs remaining: 5
# gain 1.8 age=38.0-46.0
# negs remaining: 0
# grew rule: [TSH=<0.3^T3=<0.9^age=38.0-46.0]
# prune value of [TSH=<0.3^T3=<0.9^age=38.0-46.0]: 1
# prune value of [TSH=<0.3^T3=<0.9]: 1
# prune value of [TSH=<0.3]: -0.98
# pruned rule: [TSH=<0.3^T3=<0.9]
# updated ruleset: ...[[TSH=<0.3^sick=t^T4U=1.1-1.22] V [TSH=<0.3^T3=<0.9]]
#
# rule theory bits| [TSH=<0.3^T3=<0.9] k 2 n 111 pr 0.02: 8.2 bits
# exceptions_bits| [[T3=<0.9^TSH=<0.3^sex=F] V [T3=<0.9^TSH=1.1-1.7]]...:
#  N 2530 p 288 fp 70 fn 6: exceptions_bits 303
# rule dl: 8.2
# updated theory dl: 406
# exceptions: 303
# total dl: 709
# mdl 642 dl-halt: diff 66.8 exceeds allowance (64)
# examples remaining: 6 pos, 2236 neg
#
#
# GREW INITIAL RULESET:
# [[T3=<0.9 ^ TSH=<0.3 ^ sex=F] V
# [T3=<0.9 ^ TSH=1.1-1.7] V
# [T3=0.9-1.2 ^ TSH=<0.3 ^ T4U=0.83-0.88 ^ age=70.0-76.0] V
# [T3=<0.9 ^ TSH=0.3-0.7] V
# [T3=0.9-1.2 ^ TSH=0.3-0.7] V
# [T3=0.9-1.2 ^ FTI=108.0-115.0] V
# [T3=<0.9 ^ TSH=1.7-3.2] V
# [T3=0.9-1.2 ^ TSH=<0.3] V
# [T3=<0.9 ^ TSH=<0.3 ^ age=70.0-76.0] V
# [T3=<0.9 ^ FTI=71.0-86.0 ^ query_hypothyroid=f] V
# [T3=<0.9 ^ TSH=0.7-1.1] V
# [T3=<0.9 ^ TSH=3.2-9.67 ^ sex=F ^ query_hypothyroid=t] V
# [T3=<0.9 ^ TSH=<0.3 ^ query_on_thyroxine=f ^ T4U=<0.75] V
# [T3=0.9-1.2 ^ FTI=123.0-137.0 ^ TSH=3.2-9.67] V
# [T3=0.9-1.2 ^ TSH=1.7-3.2 ^ TT4=122.0-136.0] V
# [T3=<0.9 ^ TSH=3.2-9.67 ^ age=>76.0] V
# [T3=<0.9 ^ TSH=3.2-9.67] V
# [T3=0.9-1.2 ^ TT4=63.0-78.0 ^ T4U=0.75-0.83] V
# [T3=0.9-1.2 ^ TT4=87.0-96.0] V
# [T3=<0.9 ^ TSH=<0.3 ^ TT4=104.0-112.0] V
# [T3=0.9-1.2 ^ TT4=96.0-104.0] V
# [FTI=>165.0 ^ T4U=0.88-0.92 ^ TT4=136.0-162.0 ^ on_thyroxine=f ^ T3_measured=y ^ age=31.0-38.0] V
# [T3=0.9-1.2 ^ sex=M ^ TT4=78.0-87.0 ^ FTI=86.0-94.0] V
# [FTI=>165.0 ^ age=<24.0 ^ T3=1.8-2.0] V
# [T4U=0.88-0.92 ^ age=>76.0 ^ TT4=63.0-78.0] V
# [T3=<0.9 ^ on_thyroxine=t ^ TT4=112.0-122.0] V
# [FTI=>165.0 ^ tumor=t] V
# [TT4=<63.0 ^ TSH=0.7-1.1 ^ FTI=<71.0 ^ sex=M] V
# [TSH=<0.3 ^ T3=<0.9 ^ age=54.0-59.0] V
# [FTI=>165.0 ^ T3=2.2-2.5 ^ age=>76.0] V
# [TT4=78.0-87.0 ^ T3=<0.9 ^ age=24.0-31.0] V
# [T3=0.9-1.2 ^ FTI=115.0-123.0] V
# [T3=0.9-1.2 ^ T4U=0.96-1.0 ^ age=54.0-59.0] V
# [TT4=<63.0 ^ TSH=<0.3 ^ sick=t] V
# [T4U=1.0-1.04 ^ on_antithyroid_medication=t ^ sex=M] V
# [TSH=<0.3 ^ sick=t ^ T4U=1.1-1.22] V
# [TSH=<0.3 ^ T3=<0.9]]
#
# optimization run 1 of 2
# optimizing ruleset...
#
# calculate original ruleset potential dl...
# find best potential dl for [[T3=<0.9^TSH=<0.3^sex=F] V [T3=<0.9^TSH=1.1-1.7] V [T3=0.9-1.2^TSH=<0.3^T4U=0.83-0.88^age=70.0-76.0] V [T3=<0.9^TSH=0.3-0.7] V [T3=0.9-1.2^TSH=0.3-0.7] V [T3=0.9-1.2^FTI=108.0-115.0] V [T3=<0.9^TSH=1.7-3.2] V [T3=0.9-1.2^TSH=<0.3] V [T3=<0.9^TSH=<0.3^age=70.0-76.0] V [T3=<0.9^FTI=71.0-86.0^query_hypothyroid=f] V [T3=<0.9^TSH=0.7-1.1] V [T3=<0.9^TSH=3.2-9.67^sex=F^query_hypothyroid=t] V [T3=<0.9^TSH=<0.3^query_on_thyroxine=f^T4U=<0.75] V [T3=0.9-1.2^FTI=123.0-137.0^TSH=3.2-9.67] V [T3=0.9-1.2^TSH=1.7-3.2^TT4=122.0-136.0] V [T3=<0.9^TSH=3.2-9.67^age=>76.0] V [T3=<0.9^TSH=3.2-9.67] V [T3=0.9-1.2^TT4=63.0-78.0^T4U=0.75-0.83] V [T3=0.9-1.2^TT4=87.0-96.0] V [T3=<0.9^TSH=<0.3^TT4=104.0-112.0] V [T3=0.9-1.2^TT4=96.0-104.0] V [FTI=>165.0^T4U=0.88-0.92^TT4=136.0-162.0^on_thyroxine=f^T3_measured=y^age=31.0-38.0] V [T3=0.9-1.2^sex=M^TT4=78.0-87.0^FTI=86.0-94.0] V [FTI=>165.0^age=<24.0^T3=1.8-2.0] V [T4U=0.88-0.92^age=>76.0^TT4=63.0-78.0] V [T3=<0.9^on_thyroxine=t^TT4=112.0-122.0] V [FTI=>165.0^tumor=t] V [TT4=<63.0^TSH=0.7-1.1^FTI=<71.0^sex=M] V [TSH=<0.3^T3=<0.9^age=54.0-59.0] V [FTI=>165.0^T3=2.2-2.5^age=>76.0] V [TT4=78.0-87.0^T3=<0.9^age=24.0-31.0] V [T3=0.9-1.2^FTI=115.0-123.0] V [T3=0.9-1.2^T4U=0.96-1.0^age=54.0-59.0] V [TT4=<63.0^TSH=<0.3^sick=t] V [T4U=1.0-1.04^on_antithyroid_medication=t^sex=M] V [TSH=<0.3^sick=t^T4U=1.1-1.22] V [TSH=<0.3^T3=<0.9]]:
# rule theory bits| [T3=<0.9^TSH=<0.3^sex=F] k 3 n 111 pr 0.03: 11.5 bits
# exceptions_bits| [[T3=<0.9^TSH=<0.3^sex=F]]:
#  N 2530 p 33 fp 2 fn 193: exceptions_bits 1001
# subset 0-0 | dl: 1012
# rule theory bits| [T3=<0.9^TSH=1.1-1.7] k 2 n 111 pr 0.02: 8.2 bits
# exceptions_bits| [[T3=<0.9^TSH=<0.3^sex=F] V [T3=<0.9^TSH=1.1-1.7]]:
#  N 2530 p 57 fp 2 fn 169: exceptions_bits 912
# subset 0-1 | dl: 932
# rule theory bits| [T3=0.9-1.2^TSH=<0.3^T4U=0.83-0.88^age=70.0-76.0] k 4 n 111 pr 0.04: 14.4 bits
# exceptions_bits| [[T3=<0.9^TSH=<0.3^sex=F] V [T3=<0.9^TSH=1.1-1.7]]...:
#  N 2530 p 60 fp 2 fn 166: exceptions_bits 901
# subset 0-2 | dl: 935
# rule theory bits| [T3=<0.9^TSH=0.3-0.7] k 2 n 111 pr 0.02: 8.2 bits
# exceptions_bits| [[T3=<0.9^TSH=<0.3^sex=F] V [T3=<0.9^TSH=1.1-1.7]]...:
#  N 2530 p 75 fp 3 fn 152: exceptions_bits 851
# subset 0-3 | dl: 893
# rule theory bits| [T3=0.9-1.2^TSH=0.3-0.7] k 2 n 111 pr 0.02: 8.2 bits
# exceptions_bits| [[T3=<0.9^TSH=<0.3^sex=F] V [T3=<0.9^TSH=1.1-1.7]]...:
#  N 2530 p 91 fp 8 fn 141: exceptions_bits 827
# subset 0-4 | dl: 877
# rule theory bits| [T3=0.9-1.2^FTI=108.0-115.0] k 2 n 111 pr 0.02: 8.2 bits
# exceptions_bits| [[T3=<0.9^TSH=<0.3^sex=F] V [T3=<0.9^TSH=1.1-1.7]]...:
#  N 2530 p 108 fp 11 fn 127: exceptions_bits 780
# subset 0-5 | dl: 839
# rule theory bits| [T3=<0.9^TSH=1.7-3.2] k 2 n 111 pr 0.02: 8.2 bits
# exceptions_bits| [[T3=<0.9^TSH=<0.3^sex=F] V [T3=<0.9^TSH=1.1-1.7]]...:
#  N 2530 p 124 fp 12 fn 112: exceptions_bits 721
# subset 0-6 | dl: 788
# rule theory bits| [T3=0.9-1.2^TSH=<0.3] k 2 n 111 pr 0.02: 8.2 bits
# exceptions_bits| [[T3=<0.9^TSH=<0.3^sex=F] V [T3=<0.9^TSH=1.1-1.7]]...:
#  N 2530 p 180 fp 42 fn 86: exceptions_bits 684
# subset 0-7 | dl: 759
# rule theory bits| [T3=<0.9^TSH=<0.3^age=70.0-76.0] k 3 n 111 pr 0.03: 11.5 bits
# exceptions_bits| [[T3=<0.9^TSH=<0.3^sex=F] V [T3=<0.9^TSH=1.1-1.7]]...:
#  N 2530 p 183 fp 42 fn 83: exceptions_bits 670
# subset 0-8 | dl: 757
# rule theory bits| [T3=<0.9^FTI=71.0-86.0^query_hypothyroid=f] k 3 n 111 pr 0.03: 11.5 bits
# exceptions_bits| [[T3=<0.9^TSH=<0.3^sex=F] V [T3=<0.9^TSH=1.1-1.7]]...:
#  N 2530 p 193 fp 43 fn 74: exceptions_bits 632
# subset 0-9 | dl: 730
# rule theory bits| [T3=<0.9^TSH=0.7-1.1] k 2 n 111 pr 0.02: 8.2 bits
# exceptions_bits| [[T3=<0.9^TSH=<0.3^sex=F] V [T3=<0.9^TSH=1.1-1.7]]...:
#  N 2530 p 207 fp 46 fn 63: exceptions_bits 586
# subset 0-10 | dl: 693
# rule theory bits| [T3=<0.9^TSH=3.2-9.67^sex=F^query_hypothyroid=t] k 4 n 111 pr 0.04: 14.4 bits
# exceptions_bits| [[T3=<0.9^TSH=<0.3^sex=F] V [T3=<0.9^TSH=1.1-1.7]]...:
#  N 2530 p 210 fp 46 fn 60: exceptions_bits 572
# subset 0-11 | dl: 693
# rule theory bits| [T3=<0.9^TSH=<0.3^query_on_thyroxine=f^T4U=<0.75] k 4 n 111 pr 0.04: 14.4 bits
# exceptions_bits| [[T3=<0.9^TSH=<0.3^sex=F] V [T3=<0.9^TSH=1.1-1.7]]...:
#  N 2530 p 216 fp 46 fn 54: exceptions_bits 542
# subset 0-12 | dl: 677
# rule theory bits| [T3=0.9-1.2^FTI=123.0-137.0^TSH=3.2-9.67] k 3 n 111 pr 0.03: 11.5 bits
# exceptions_bits| [[T3=<0.9^TSH=<0.3^sex=F] V [T3=<0.9^TSH=1.1-1.7]]...:
#  N 2530 p 218 fp 46 fn 52: exceptions_bits 532
# subset 0-13 | dl: 679
# rule theory bits| [T3=0.9-1.2^TSH=1.7-3.2^TT4=122.0-136.0] k 3 n 111 pr 0.03: 11.5 bits
# exceptions_bits| [[T3=<0.9^TSH=<0.3^sex=F] V [T3=<0.9^TSH=1.1-1.7]]...:
#  N 2530 p 221 fp 46 fn 49: exceptions_bits 516
# subset 0-14 | dl: 675
# rule theory bits| [T3=<0.9^TSH=3.2-9.67^age=>76.0] k 3 n 111 pr 0.03: 11.5 bits
# exceptions_bits| [[T3=<0.9^TSH=<0.3^sex=F] V [T3=<0.9^TSH=1.1-1.7]]...:
#  N 2530 p 225 fp 47 fn 46: exceptions_bits 503
# subset 0-15 | dl: 673
# rule theory bits| [T3=<0.9^TSH=3.2-9.67] k 2 n 111 pr 0.02: 8.2 bits
# exceptions_bits| [[T3=<0.9^TSH=<0.3^sex=F] V [T3=<0.9^TSH=1.1-1.7]]...:
#  N 2530 p 237 fp 52 fn 39: exceptions_bits 476
# subset 0-16 | dl: 654
# rule theory bits| [T3=0.9-1.2^TT4=63.0-78.0^T4U=0.75-0.83] k 3 n 111 pr 0.03: 11.5 bits
# exceptions_bits| [[T3=<0.9^TSH=<0.3^sex=F] V [T3=<0.9^TSH=1.1-1.7]]...:
#  N 2530 p 240 fp 52 fn 36: exceptions_bits 459
# subset 0-17 | dl: 649
# rule theory bits| [T3=0.9-1.2^TT4=87.0-96.0] k 2 n 111 pr 0.02: 8.2 bits
# exceptions_bits| [[T3=<0.9^TSH=<0.3^sex=F] V [T3=<0.9^TSH=1.1-1.7]]...:
#  N 2530 p 247 fp 56 fn 33: exceptions_bits 451
# subset 0-18 | dl: 649
# rule theory bits| [T3=<0.9^TSH=<0.3^TT4=104.0-112.0] k 3 n 111 pr 0.03: 11.5 bits
# exceptions_bits| [[T3=<0.9^TSH=<0.3^sex=F] V [T3=<0.9^TSH=1.1-1.7]]...:
#  N 2530 p 249 fp 56 fn 31: exceptions_bits 439
# subset 0-19 | dl: 649
# rule theory bits| [T3=0.9-1.2^TT4=96.0-104.0] k 2 n 111 pr 0.02: 8.2 bits
# exceptions_bits| [[T3=<0.9^TSH=<0.3^sex=F] V [T3=<0.9^TSH=1.1-1.7]]...:
#  N 2530 p 257 fp 60 fn 27: exceptions_bits 424
# subset 0-20 | dl: 642
# rule theory bits| [FTI=>165.0^T4U=0.88-0.92^TT4=136.0-162.0^on_thyroxine=f^T3_measured=y^age=31.0-38.0] k 6 n 111 pr 0.05: 19.4 bits
# exceptions_bits| [[T3=<0.9^TSH=<0.3^sex=F] V [T3=<0.9^TSH=1.1-1.7]]...:
#  N 2530 p 258 fp 60 fn 26: exceptions_bits 418
# subset 0-21 | dl: 655
# rule theory bits| [T3=0.9-1.2^sex=M^TT4=78.0-87.0^FTI=86.0-94.0] k 4 n 111 pr 0.04: 14.4 bits
# exceptions_bits| [[T3=<0.9^TSH=<0.3^sex=F] V [T3=<0.9^TSH=1.1-1.7]]...:
#  N 2530 p 261 fp 61 fn 24: exceptions_bits 408
# subset 0-22 | dl: 660
# rule theory bits| [FTI=>165.0^age=<24.0^T3=1.8-2.0] k 3 n 111 pr 0.03: 11.5 bits
# exceptions_bits| [[T3=<0.9^TSH=<0.3^sex=F] V [T3=<0.9^TSH=1.1-1.7]]...:
#  N 2530 p 263 fp 62 fn 23: exceptions_bits 404
# subset 0-23 | dl: 667
# rule theory bits| [T4U=0.88-0.92^age=>76.0^TT4=63.0-78.0] k 3 n 111 pr 0.03: 11.5 bits
# exceptions_bits| [[T3=<0.9^TSH=<0.3^sex=F] V [T3=<0.9^TSH=1.1-1.7]]...:
#  N 2530 p 267 fp 64 fn 21: exceptions_bits 396
# subset 0-24 | dl: 670
# rule theory bits| [T3=<0.9^on_thyroxine=t^TT4=112.0-122.0] k 3 n 111 pr 0.03: 11.5 bits
# exceptions_bits| [[T3=<0.9^TSH=<0.3^sex=F] V [T3=<0.9^TSH=1.1-1.7]]...:
#  N 2530 p 269 fp 64 fn 19: exceptions_bits 383
# subset 0-25 | dl: 669
# rule theory bits| [FTI=>165.0^tumor=t] k 2 n 111 pr 0.02: 8.2 bits
# exceptions_bits| [[T3=<0.9^TSH=<0.3^sex=F] V [T3=<0.9^TSH=1.1-1.7]]...:
#  N 2530 p 270 fp 64 fn 18: exceptions_bits 376
# subset 0-26 | dl: 671
# rule theory bits| [TT4=<63.0^TSH=0.7-1.1^FTI=<71.0^sex=M] k 4 n 111 pr 0.04: 14.4 bits
# exceptions_bits| [[T3=<0.9^TSH=<0.3^sex=F] V [T3=<0.9^TSH=1.1-1.7]]...:
#  N 2530 p 274 fp 65 fn 15: exceptions_bits 358
# subset 0-27 | dl: 667
# rule theory bits| [TSH=<0.3^T3=<0.9^age=54.0-59.0] k 3 n 111 pr 0.03: 11.5 bits
# exceptions_bits| [[T3=<0.9^TSH=<0.3^sex=F] V [T3=<0.9^TSH=1.1-1.7]]...:
#  N 2530 p 275 fp 65 fn 14: exceptions_bits 352
# subset 0-28 | dl: 672
# rule theory bits| [FTI=>165.0^T3=2.2-2.5^age=>76.0] k 3 n 111 pr 0.03: 11.5 bits
# exceptions_bits| [[T3=<0.9^TSH=<0.3^sex=F] V [T3=<0.9^TSH=1.1-1.7]]...:
#  N 2530 p 276 fp 65 fn 13: exceptions_bits 345
# subset 0-29 | dl: 677
# rule theory bits| [TT4=78.0-87.0^T3=<0.9^age=24.0-31.0] k 3 n 111 pr 0.03: 11.5 bits
# exceptions_bits| [[T3=<0.9^TSH=<0.3^sex=F] V [T3=<0.9^TSH=1.1-1.7]]...:
#  N 2530 p 277 fp 65 fn 12: exceptions_bits 338
# subset 0-30 | dl: 681
# rule theory bits| [T3=0.9-1.2^FTI=115.0-123.0] k 2 n 111 pr 0.02: 8.2 bits
# exceptions_bits| [[T3=<0.9^TSH=<0.3^sex=F] V [T3=<0.9^TSH=1.1-1.7]]...:
#  N 2530 p 278 fp 65 fn 11: exceptions_bits 330
# subset 0-31 | dl: 682
# rule theory bits| [T3=0.9-1.2^T4U=0.96-1.0^age=54.0-59.0] k 3 n 111 pr 0.03: 11.5 bits
# exceptions_bits| [[T3=<0.9^TSH=<0.3^sex=F] V [T3=<0.9^TSH=1.1-1.7]]...:
#  N 2530 p 279 fp 65 fn 10: exceptions_bits 323
# subset 0-32 | dl: 686
# rule theory bits| [TT4=<63.0^TSH=<0.3^sick=t] k 3 n 111 pr 0.03: 11.5 bits
# exceptions_bits| [[T3=<0.9^TSH=<0.3^sex=F] V [T3=<0.9^TSH=1.1-1.7]]...:
#  N 2530 p 280 fp 65 fn 9: exceptions_bits 316
# subset 0-33 | dl: 690
# rule theory bits| [T4U=1.0-1.04^on_antithyroid_medication=t^sex=M] k 3 n 111 pr 0.03: 11.5 bits
# exceptions_bits| [[T3=<0.9^TSH=<0.3^sex=F] V [T3=<0.9^TSH=1.1-1.7]]...:
#  N 2530 p 281 fp 65 fn 8: exceptions_bits 308
# subset 0-34 | dl: 694
# rule theory bits| [TSH=<0.3^sick=t^T4U=1.1-1.22] k 3 n 111 pr 0.03: 11.5 bits
# exceptions_bits| [[T3=<0.9^TSH=<0.3^sex=F] V [T3=<0.9^TSH=1.1-1.7]]...:
#  N 2530 p 282 fp 65 fn 7: exceptions_bits 300
# subset 0-35 | dl: 698
# rule theory bits| [TSH=<0.3^T3=<0.9] k 2 n 111 pr 0.02: 8.2 bits
# exceptions_bits| [[T3=<0.9^TSH=<0.3^sex=F] V [T3=<0.9^TSH=1.1-1.7]]...:
#  N 2530 p 288 fp 70 fn 6: exceptions_bits 303
# subset 0-36 | dl: 709
# subset dls: [(0, 1012), (1, 932), (2, 935), (3, 893), (4, 877), (5, 839), (6, 788), (7, 759), (8, 757), (9, 730), (10, 693), (11, 693), (12, 677), (13, 679), (14, 675), (15, 673), (16, 654), (17, 649), (18, 649), (19, 649), (20, 642), (21, 655), (22, 660), (23, 667), (24, 670), (25, 669), (26, 671), (27, 667), (28, 672), (29, 677), (30, 681), (31, 682), (32, 686), (33, 690), (34, 694), (35, 698), (36, 709)]
# best potential ruleset: [[T3=<0.9^TSH=<0.3^sex=F] V [T3=<0.9^TSH=1.1-1.7] V [T3=<0.9^TSH=0.3-0.7] V [T3=0.9-1.2^TSH=0.3-0.7] V [T3=0.9-1.2^FTI=108.0-115.0] V [T3=<0.9^TSH=1.7-3.2] V [T3=0.9-1.2^TSH=<0.3] V [T3=<0.9^TSH=<0.3^age=70.0-76.0] V [T3=<0.9^FTI=71.0-86.0^query_hypothyroid=f] V [T3=<0.9^TSH=0.7-1.1] V [T3=<0.9^TSH=3.2-9.67^sex=F^query_hypothyroid=t] V [T3=<0.9^TSH=<0.3^query_on_thyroxine=f^T4U=<0.75] V [T3=0.9-1.2^TSH=1.7-3.2^TT4=122.0-136.0] V [T3=<0.9^TSH=3.2-9.67^age=>76.0] V [T3=<0.9^TSH=3.2-9.67] V [T3=0.9-1.2^TT4=63.0-78.0^T4U=0.75-0.83] V [T3=0.9-1.2^TT4=87.0-96.0] V [T3=0.9-1.2^TT4=96.0-104.0] V [T3=<0.9^on_thyroxine=t^TT4=112.0-122.0] V [TT4=<63.0^TSH=0.7-1.1^FTI=<71.0^sex=M]]
# best potential dl was 631
#
# original ruleset potential dl: 631
#
# creating replacement for 0 of 37: [T3=<0.9^TSH=<0.3^sex=F]
# growing rule from initial rule: [True]
# gain 253 T3=<0.9
# negs remaining: 51
# gain 15.4 TSH=<0.3
# negs remaining: 3
# gain 2.4 sex=F
# negs remaining: 0
# grew rule: [T3=<0.9^TSH=<0.3^sex=F]
# prune value of [T3=<0.9^TSH=<0.3^sex=F]: 0.92
# prune value of [T3=<0.9^TSH=<0.3]: 0.92
# prune value of [T3=<0.9]: 0.92
# grew replacement [T3=<0.9^TSH=<0.3^sex=F]
# pruned replacement is [T3=<0.9^TSH=<0.3]
# creating revision for 0 of 37: [T3=<0.9^TSH=<0.3^sex=F]
# growing rule from initial rule: [T3=<0.9^TSH=<0.3^sex=F]
# grew rule: [T3=<0.9^TSH=<0.3^sex=F]
# prune value of [T3=<0.9^TSH=<0.3^sex=F]: 0.92
# prune value of [T3=<0.9^TSH=<0.3]: 0.92
# prune value of [T3=<0.9]: 0.92
# grew revision [T3=<0.9^TSH=<0.3^sex=F]
# pruned revision is [T3=<0.9^TSH=<0.3]
#
# calculate potential dl for ds with replacement [T3=<0.9^TSH=<0.3]
# calculate potential dl for ds with revision [T3=<0.9^TSH=<0.3]
#
# rule 1 of 37
# original: [T3=<0.9^TSH=<0.3^sex=F]) | 631 bits
# replacement: [T3=<0.9^TSH=<0.3] | 711 bits
# revision: [T3=<0.9^TSH=<0.3] | 711 bits
# *best: unchanged | 631 bits
# best already included in optimization -- retaining original
#
# examples remaining: 193 pos, 2304 neg
#
# creating replacement for 1 of 37: [T3=<0.9^TSH=1.1-1.7]
# growing rule from initial rule: [True]
# gain 186 T3=<0.9
# negs remaining: 64
# gain 19.9 TSH=1.1-1.7
# negs remaining: 0
# grew rule: [T3=<0.9^TSH=1.1-1.7]
# prune value of [T3=<0.9^TSH=1.1-1.7]: 0.93
# prune value of [T3=<0.9]: 0.93
# grew replacement [T3=<0.9^TSH=1.1-1.7]
# pruned replacement is [T3=<0.9]
# creating revision for 1 of 37: [T3=<0.9^TSH=1.1-1.7]
# growing rule from initial rule: [T3=<0.9^TSH=1.1-1.7]
# grew rule: [T3=<0.9^TSH=1.1-1.7]
# prune value of [T3=<0.9^TSH=1.1-1.7]: 0.93
# prune value of [T3=<0.9]: 0.93
# grew revision [T3=<0.9^TSH=1.1-1.7]
# pruned revision is [T3=<0.9]
#
# calculate potential dl for ds with replacement [T3=<0.9]
# calculate potential dl for ds with revision [T3=<0.9]
#
# rule 2 of 37
# original: [T3=<0.9^TSH=1.1-1.7]) | 631 bits
# replacement: [T3=<0.9] | 827 bits
# revision: [T3=<0.9] | 827 bits
# *best: unchanged | 631 bits
# best already included in optimization -- retaining original
#
# examples remaining: 169 pos, 2304 neg
#
# creating replacement for 2 of 37: [T3=0.9-1.2^TSH=<0.3^T4U=0.83-0.88^age=70.0-76.0]
# growing rule from initial rule: [True]
# gain 153 T3=<0.9
# negs remaining: 63
# ...
# [T3=<0.9 ^ TSH=3.3-9.8] V
# [T3=0.9-1.2 ^ TSH=<0.3 ^ FTI=86.0-94.0] V
# [T3=<0.9 ^ FTI=107.0-114.0] V
# [T3=0.9-1.2 ^ TSH=0.3-0.7 ^ age=64.0-70.0] V
# [T3=0.9-1.2 ^ TSH=<0.3 ^ TT4=95.0-104.0] V
# [T3=0.9-1.2 ^ age=>76.0 ^ sex=M ^ FTI=94.0-101.0] V
# [T3=<0.9 ^ TSH=0.3-0.7] V
# [T3=<0.9 ^ TSH=1.8-3.3] V
# [T3=0.9-1.2 ^ TSH=<0.3 ^ T4U=<0.76 ^ TT4=63.0-78.0] V
# [T3=0.9-1.2 ^ FTI=101.0-107.0 ^ TSH=0.3-0.7] V
# [T3=0.9-1.2 ^ TSH=<0.3 ^ age=>76.0 ^ TT4=121.0-135.0] V
# [T3=<0.9 ^ TSH=0.7-1.18] V
# [T3=0.9-1.2 ^ age=53.0-59.0 ^ sex=F] V
# [T3=0.9-1.2 ^ TT4=78.0-87.0 ^ FTI=114.0-122.0 ^ age=59.0-64.0] V
# [T3=0.9-1.2 ^ TSH=1.8-3.3 ^ T4U=0.83-0.88] V
# [FTI=>166.0 ^ T4U=0.88-0.92 ^ on_thyroxine=f ^ age=32.0-38.0] V
# [T3=0.9-1.2 ^ TSH=0.7-1.18 ^ age=70.0-76.0] V
# [FTI=>166.0 ^ T3=2.5-3.0 ^ T4U=0.83-0.88] V
# [T3=<0.9 ^ FTI=71.0-86.0] V
# [T3=0.9-1.2 ^ TSH=<0.3 ^ FTI=<71.0] V
# [age=>76.0 ^ T3=<0.9 ^ on_thyroxine=t] V
# [T3=0.9-1.2 ^ TSH=<0.3 ^ age=53.0-59.0] V
# [TT4=>163.0 ^ age=64.0-70.0 ^ on_thyroxine=f ^ query_hyperthyroid=f ^ tumor=t] V
# [T3=0.9-1.2 ^ TT4=78.0-87.0 ^ TSH=1.18-1.8] V
# [FTI=<71.0 ^ TSH=<0.3 ^ sick=t] V
# [TSH=<0.3 ^ T3=0.9-1.2 ^ T4U=1.0-1.04] V
# [T3=<0.9 ^ T4U=0.76-0.83] V
# [T3=<0.9 ^ T4U=<0.76 ^ TT4=63.0-78.0] V
# [T3=<0.9 ^ T4U=<0.76 ^ FTI=136.0-166.0] V
# [T3=<0.9 ^ TSH=1.18-1.8] V
# [T3=0.9-1.2 ^ FTI=122.0-136.0] V
# [T3=0.9-1.2 ^ FTI=107.0-114.0 ^ T4U=<0.76] V
# [T3=<0.9 ^ T4U=<0.76 ^ on_thyroxine=f ^ FTI=71.0-86.0]]
#
# Optimizing dl...
# find best potential dl for [[T3=<0.9^T4U=<0.76] V [T3=<0.9^T4U=0.76-0.83^age=70.0-76.0] V [T3=0.9-1.2^TSH=0.3-0.7^age=59.0-64.0] V [T3=0.9-1.2^T4U=0.88-0.92^TSH=<0.3] V [T3=0.9-1.2^T4U=<0.76^TT4=87.0-95.0] V [T3=<0.9^T4U=0.76-0.83^age=64.0-70.0] V [T3=0.9-1.2^FTI=122.0-136.0] V [T3=<0.9^TSH=1.18-1.8] V [T3=0.9-1.2^age=70.0-76.0^sex=M] V [T3=<0.9^TSH=<0.3^sex=F] V [T3=0.9-1.2^FTI=107.0-114.0^T4U=<0.76] V [T3=0.9-1.2^T4U=0.88-0.92^sick=f^TSH=1.8-3.3] V [T3=0.9-1.2^FTI=107.0-114.0^query_hypothyroid=f] V [T3=<0.9^TSH=3.3-9.8] V [T3=0.9-1.2^TSH=<0.3^FTI=86.0-94.0] V [T3=<0.9^FTI=107.0-114.0] V [T3=0.9-1.2^TSH=0.3-0.7^age=64.0-70.0] V [T3=0.9-1.2^TSH=<0.3^TT4=95.0-104.0] V [T3=0.9-1.2^age=>76.0^sex=M^FTI=94.0-101.0] V [T3=<0.9^TSH=0.3-0.7] V [T3=<0.9^TSH=1.8-3.3] V [T3=0.9-1.2^TSH=<0.3^T4U=<0.76^TT4=63.0-78.0] V [T3=0.9-1.2^FTI=101.0-107.0^TSH=0.3-0.7] V [T3=0.9-1.2^TSH=<0.3^age=>76.0^TT4=121.0-135.0] V [T3=<0.9^TSH=0.7-1.18] V [T3=0.9-1.2^age=53.0-59.0^sex=F] V [T3=0.9-1.2^TT4=78.0-87.0^FTI=114.0-122.0^age=59.0-64.0] V [T3=0.9-1.2^TSH=1.8-3.3^T4U=0.83-0.88] V [FTI=>166.0^T4U=0.88-0.92^on_thyroxine=f^age=32.0-38.0] V [T3=0.9-1.2^TSH=0.7-1.18^age=70.0-76.0] V [FTI=>166.0^T3=2.5-3.0^T4U=0.83-0.88] V [T3=<0.9^FTI=71.0-86.0] V [T3=0.9-1.2^TSH=<0.3^FTI=<71.0] V [age=>76.0^T3=<0.9^on_thyroxine=t] V [T3=0.9-1.2^TSH=<0.3^age=53.0-59.0] V [TT4=>163.0^age=64.0-70.0^on_thyroxine=f^query_hyperthyroid=f^tumor=t] V [T3=0.9-1.2^TT4=78.0-87.0^TSH=1.18-1.8] V [FTI=<71.0^TSH=<0.3^sick=t] V [TSH=<0.3^T3=0.9-1.2^T4U=1.0-1.04] V [T3=<0.9^T4U=0.76-0.83] V [T3=<0.9^T4U=<0.76^TT4=63.0-78.0] V [T3=<0.9^T4U=<0.76^FTI=136.0-166.0] V [T3=<0.9^TSH=1.18-1.8] V [T3=0.9-1.2^FTI=122.0-136.0] V [T3=0.9-1.2^FTI=107.0-114.0^T4U=<0.76] V [T3=<0.9^T4U=<0.76^on_thyroxine=f^FTI=71.0-86.0]]:
# rule theory bits| [T3=<0.9^T4U=<0.76] k 2 n 111 pr 0.02: 8.2 bits
# exceptions_bits| [[T3=<0.9^T4U=<0.76]]:
#  N 2530 p 67 fp 17 fn 178: exceptions_bits 986
# subset 0-0 | dl: 994
# rule theory bits| [T3=<0.9^T4U=0.76-0.83^age=70.0-76.0] k 3 n 111 pr 0.03: 11.5 bits
# exceptions_bits| [[T3=<0.9^T4U=<0.76] V [T3=<0.9^T4U=0.76-0.83^age=70.0-76.0]]:
#  N 2530 p 76 fp 17 fn 169: exceptions_bits 955
# subset 0-1 | dl: 975
# rule theory bits| [T3=0.9-1.2^TSH=0.3-0.7^age=59.0-64.0] k 3 n 111 pr 0.03: 11.5 bits
# exceptions_bits| [[T3=<0.9^T4U=<0.76] V [T3=<0.9^T4U=0.76-0.83^age=70.0-76.0]]...:
#  N 2530 p 79 fp 17 fn 166: exceptions_bits 945
# subset 0-2 | dl: 976
# rule theory bits| [T3=0.9-1.2^T4U=0.88-0.92^TSH=<0.3] k 3 n 111 pr 0.03: 11.5 bits
# exceptions_bits| [[T3=<0.9^T4U=<0.76] V [T3=<0.9^T4U=0.76-0.83^age=70.0-76.0]]...:
#  N 2530 p 89 fp 18 fn 157: exceptions_bits 915
# subset 0-3 | dl: 958
# rule theory bits| [T3=0.9-1.2^T4U=<0.76^TT4=87.0-95.0] k 3 n 111 pr 0.03: 11.5 bits
# exceptions_bits| [[T3=<0.9^T4U=<0.76] V [T3=<0.9^T4U=0.76-0.83^age=70.0-76.0]]...:
#  N 2530 p 95 fp 20 fn 153: exceptions_bits 905
# subset 0-4 | dl: 959
# rule theory bits| [T3=<0.9^T4U=0.76-0.83^age=64.0-70.0] k 3 n 111 pr 0.03: 11.5 bits
# exceptions_bits| [[T3=<0.9^T4U=<0.76] V [T3=<0.9^T4U=0.76-0.83^age=70.0-76.0]]...:
#  N 2530 p 102 fp 20 fn 146: exceptions_bits 879
# subset 0-5 | dl: 945
# rule theory bits| [T3=0.9-1.2^FTI=122.0-136.0] k 2 n 111 pr 0.02: 8.2 bits
# exceptions_bits| [[T3=<0.9^T4U=<0.76] V [T3=<0.9^T4U=0.76-0.83^age=70.0-76.0]]...:
#  N 2530 p 119 fp 24 fn 133: exceptions_bits 839
# subset 0-6 | dl: 913
# rule theory bits| [T3=<0.9^TSH=1.18-1.8] k 2 n 111 pr 0.02: 8.2 bits
# exceptions_bits| [[T3=<0.9^T4U=<0.76] V [T3=<0.9^T4U=0.76-0.83^age=70.0-76.0]]...:
#  N 2530 p 134 fp 24 fn 118: exceptions_bits 779
# subset 0-7 | dl: 862
# rule theory bits| [T3=0.9-1.2^age=70.0-76.0^sex=M] k 3 n 111 pr 0.03: 11.5 bits
# exceptions_bits| [[T3=<0.9^T4U=<0.76] V [T3=<0.9^T4U=0.76-0.83^age=70.0-76.0]]...:
#  N 2530 p 142 fp 26 fn 112: exceptions_bits 760
# subset 0-8 | dl: 854
# rule theory bits| [T3=<0.9^TSH=<0.3^sex=F] k 3 n 111 pr 0.03: 11.5 bits
# exceptions_bits| [[T3=<0.9^T4U=<0.76] V [T3=<0.9^T4U=0.76-0.83^age=70.0-76.0]]...:
#  N 2530 p 156 fp 28 fn 100: exceptions_bits 714
# subset 0-9 | dl: 820
# rule theory bits| [T3=0.9-1.2^FTI=107.0-114.0^T4U=<0.76] k 3 n 111 pr 0.03: 11.5 bits
# exceptions_bits| [[T3=<0.9^T4U=<0.76] V [T3=<0.9^T4U=0.76-0.83^age=70.0-76.0]]...:
#  N 2530 p 161 fp 28 fn 95: exceptions_bits 693
# subset 0-10 | dl: 810
# rule theory bits| [T3=0.9-1.2^T4U=0.88-0.92^sick=f^TSH=1.8-3.3] k 4 n 111 pr 0.04: 14.4 bits
# exceptions_bits| [[T3=<0.9^T4U=<0.76] V [T3=<0.9^T4U=0.76-0.83^age=70.0-76.0]]...:
#  N 2530 p 166 fp 30 fn 92: exceptions_bits 685
# subset 0-11 | dl: 816
# rule theory bits| [T3=0.9-1.2^FTI=107.0-114.0^query_hypothyroid=f] k 3 n 111 pr 0.03: 11.5 bits
# exceptions_bits| [[T3=<0.9^T4U=<0.76] V [T3=<0.9^T4U=0.76-0.83^age=70.0-76.0]]...:
#  N 2530 p 173 fp 31 fn 86: exceptions_bits 660
# subset 0-12 | dl: 803
# rule theory bits| [T3=<0.9^TSH=3.3-9.8] k 2 n 111 pr 0.02: 8.2 bits
# exceptions_bits| [[T3=<0.9^T4U=<0.76] V [T3=<0.9^T4U=0.76-0.83^age=70.0-76.0]]...:
#  N 2530 p 184 fp 33 fn 77: exceptions_bits 624
# subset 0-13 | dl: 775
# rule theory bits| [T3=0.9-1.2^TSH=<0.3^FTI=86.0-94.0] k 3 n 111 pr 0.03: 11.5 bits
# exceptions_bits| [[T3=<0.9^T4U=<0.76] V [T3=<0.9^T4U=0.76-0.83^age=70.0-76.0]]...:
#  N 2530 p 191 fp 35 fn 72: exceptions_bits 606
# subset 0-14 | dl: 768
# rule theory bits| [T3=<0.9^FTI=107.0-114.0] k 2 n 111 pr 0.02: 8.2 bits
# exceptions_bits| [[T3=<0.9^T4U=<0.76] V [T3=<0.9^T4U=0.76-0.83^age=70.0-76.0]]...:
#  N 2530 p 198 fp 36 fn 66: exceptions_bits 579
# subset 0-15 | dl: 750
# rule theory bits| [T3=0.9-1.2^TSH=0.3-0.7^age=64.0-70.0] k 3 n 111 pr 0.03: 11.5 bits
# exceptions_bits| [[T3=<0.9^T4U=<0.76] V [T3=<0.9^T4U=0.76-0.83^age=70.0-76.0]]...:
#  N 2530 p 201 fp 36 fn 63: exceptions_bits 565
# subset 0-16 | dl: 747
# rule theory bits| [T3=0.9-1.2^TSH=<0.3^TT4=95.0-104.0] k 3 n 111 pr 0.03: 11.5 bits
# exceptions_bits| [[T3=<0.9^T4U=<0.76] V [T3=<0.9^T4U=0.76-0.83^age=70.0-76.0]]...:
#  N 2530 p 207 fp 38 fn 59: exceptions_bits 550
# subset 0-17 | dl: 744
# rule theory bits| [T3=0.9-1.2^age=>76.0^sex=M^FTI=94.0-101.0] k 4 n 111 pr 0.04: 14.4 bits
# exceptions_bits| [[T3=<0.9^T4U=<0.76] V [T3=<0.9^T4U=0.76-0.83^age=70.0-76.0]]...:
#  N 2530 p 211 fp 40 fn 57: exceptions_bits 545
# subset 0-18 | dl: 753
# rule theory bits| [T3=<0.9^TSH=0.3-0.7] k 2 n 111 pr 0.02: 8.2 bits
# exceptions_bits| [[T3=<0.9^T4U=<0.76] V [T3=<0.9^T4U=0.76-0.83^age=70.0-76.0]]...:
#  N 2530 p 217 fp 40 fn 51: exceptions_bits 514
# subset 0-19 | dl: 731
# rule theory bits| [T3=<0.9^TSH=1.8-3.3] k 2 n 111 pr 0.02: 8.2 bits
# exceptions_bits| [[T3=<0.9^T4U=<0.76] V [T3=<0.9^T4U=0.76-0.83^age=70.0-76.0]]...:
#  N 2530 p 223 fp 40 fn 45: exceptions_bits 482
# subset 0-20 | dl: 707
# rule theory bits| [T3=0.9-1.2^TSH=<0.3^T4U=<0.76^TT4=63.0-78.0] k 4 n 111 pr 0.04: 14.4 bits
# exceptions_bits| [[T3=<0.9^T4U=<0.76] V [T3=<0.9^T4U=0.76-0.83^age=70.0-76.0]]...:
#  N 2530 p 225 fp 40 fn 43: exceptions_bits 471
# subset 0-21 | dl: 711
# rule theory bits| [T3=0.9-1.2^FTI=101.0-107.0^TSH=0.3-0.7] k 3 n 111 pr 0.03: 11.5 bits
# exceptions_bits| [[T3=<0.9^T4U=<0.76] V [T3=<0.9^T4U=0.76-0.83^age=70.0-76.0]]...:
#  N 2530 p 227 fp 40 fn 41: exceptions_bits 461
# subset 0-22 | dl: 711
# rule theory bits| [T3=0.9-1.2^TSH=<0.3^age=>76.0^TT4=121.0-135.0] k 4 n 111 pr 0.04: 14.4 bits
# exceptions_bits| [[T3=<0.9^T4U=<0.76] V [T3=<0.9^T4U=0.76-0.83^age=70.0-76.0]]...:
#  N 2530 p 228 fp 40 fn 40: exceptions_bits 455
# subset 0-23 | dl: 720
# rule theory bits| [T3=<0.9^TSH=0.7-1.18] k 2 n 111 pr 0.02: 8.2 bits
# exceptions_bits| [[T3=<0.9^T4U=<0.76] V [T3=<0.9^T4U=0.76-0.83^age=70.0-76.0]]...:
#  N 2530 p 233 fp 41 fn 36: exceptions_bits 435
# subset 0-24 | dl: 708
# rule theory bits| [T3=0.9-1.2^age=53.0-59.0^sex=F] k 3 n 111 pr 0.03: 11.5 bits
# exceptions_bits| [[T3=<0.9^T4U=<0.76] V [T3=<0.9^T4U=0.76-0.83^age=70.0-76.0]]...:
#  N 2530 p 238 fp 44 fn 34: exceptions_bits 431
# subset 0-25 | dl: 716
# rule theory bits| [T3=0.9-1.2^TT4=78.0-87.0^FTI=114.0-122.0^age=59.0-64.0] k 4 n 111 pr 0.04: 14.4 bits
# exceptions_bits| [[T3=<0.9^T4U=<0.76] V [T3=<0.9^T4U=0.76-0.83^age=70.0-76.0]]...:
#  N 2530 p 239 fp 44 fn 33: exceptions_bits 425
# subset 0-26 | dl: 724
# rule theory bits| [T3=0.9-1.2^TSH=1.8-3.3^T4U=0.83-0.88] k 3 n 111 pr 0.03: 11.5 bits
# exceptions_bits| [[T3=<0.9^T4U=<0.76] V [T3=<0.9^T4U=0.76-0.83^age=70.0-76.0]]...:
#  N 2530 p 242 fp 45 fn 31: exceptions_bits 416
# subset 0-27 | dl: 727
# rule theory bits| [FTI=>166.0^T4U=0.88-0.92^on_thyroxine=f^age=32.0-38.0] k 4 n 111 pr 0.04: 14.4 bits
# exceptions_bits| [[T3=<0.9^T4U=<0.76] V [T3=<0.9^T4U=0.76-0.83^age=70.0-76.0]]...:
#  N 2530 p 243 fp 45 fn 30: exceptions_bits 410
# subset 0-28 | dl: 735
# rule theory bits| [T3=0.9-1.2^TSH=0.7-1.18^age=70.0-76.0] k 3 n 111 pr 0.03: 11.5 bits
# exceptions_bits| [[T3=<0.9^T4U=<0.76] V [T3=<0.9^T4U=0.76-0.83^age=70.0-76.0]]...:
#  N 2530 p 245 fp 45 fn 28: exceptions_bits 398
# subset 0-29 | dl: 735
# rule theory bits| [FTI=>166.0^T3=2.5-3.0^T4U=0.83-0.88] k 3 n 111 pr 0.03: 11.5 bits
# exceptions_bits| [[T3=<0.9^T4U=<0.76] V [T3=<0.9^T4U=0.76-0.83^age=70.0-76.0]]...:
#  N 2530 p 248 fp 46 fn 26: exceptions_bits 388
# subset 0-30 | dl: 737
# rule theory bits| [T3=<0.9^FTI=71.0-86.0] k 2 n 111 pr 0.02: 8.2 bits
# exceptions_bits| [[T3=<0.9^T4U=<0.76] V [T3=<0.9^T4U=0.76-0.83^age=70.0-76.0]]...:
#  N 2530 p 251 fp 47 fn 24: exceptions_bits 378
# subset 0-31 | dl: 735
# rule theory bits| [T3=0.9-1.2^TSH=<0.3^FTI=<71.0] k 3 n 111 pr 0.03: 11.5 bits
# exceptions_bits| [[T3=<0.9^T4U=<0.76] V [T3=<0.9^T4U=0.76-0.83^age=70.0-76.0]]...:
#  N 2530 p 255 fp 49 fn 22: exceptions_bits 370
# subset 0-32 | dl: 739
# rule theory bits| [age=>76.0^T3=<0.9^on_thyroxine=t] k 3 n 111 pr 0.03: 11.5 bits
# exceptions_bits| [[T3=<0.9^T4U=<0.76] V [T3=<0.9^T4U=0.76-0.83^age=70.0-76.0]]...:
#  N 2530 p 258 fp 50 fn 20: exceptions_bits 360
# subset 0-33 | dl: 740
# rule theory bits| [T3=0.9-1.2^TSH=<0.3^age=53.0-59.0] k 3 n 111 pr 0.03: 11.5 bits
# exceptions_bits| [[T3=<0.9^T4U=<0.76] V [T3=<0.9^T4U=0.76-0.83^age=70.0-76.0]]...:
#  N 2530 p 261 fp 52 fn 19: exceptions_bits 358
# subset 0-34 | dl: 749
# rule theory bits| [TT4=>163.0^age=64.0-70.0^on_thyroxine=f^query_hyperthyroid=f^tumor=t] k 5 n 111 pr 0.05: 17 bits
# exceptions_bits| [[T3=<0.9^T4U=<0.76] V [T3=<0.9^T4U=0.76-0.83^age=70.0-76.0]]...:
#  N 2530 p 262 fp 52 fn 18: exceptions_bits 352
# subset 0-35 | dl: 760
# rule theory bits| [T3=0.9-1.2^TT4=78.0-87.0^TSH=1.18-1.8] k 3 n 111 pr 0.03: 11.5 bits
# exceptions_bits| [[T3=<0.9^T4U=<0.76] V [T3=<0.9^T4U=0.76-0.83^age=70.0-76.0]]...:
#  N 2530 p 263 fp 52 fn 17: exceptions_bits 345
# subset 0-36 | dl: 765
# rule theory bits| [FTI=<71.0^TSH=<0.3^sick=t] k 3 n 111 pr 0.03: 11.5 bits
# exceptions_bits| [[T3=<0.9^T4U=<0.76] V [T3=<0.9^T4U=0.76-0.83^age=70.0-76.0]]...:
#  N 2530 p 264 fp 52 fn 16: exceptions_bits 338
# subset 0-37 | dl: 769
# rule theory bits| [TSH=<0.3^T3=0.9-1.2^T4U=1.0-1.04] k 3 n 111 pr 0.03: 11.5 bits
# exceptions_bits| [[T3=<0.9^T4U=<0.76] V [T3=<0.9^T4U=0.76-0.83^age=70.0-76.0]]...:
#  N 2530 p 267 fp 54 fn 15: exceptions_bits 336
# subset 0-38 | dl: 779
# rule theory bits| [T3=<0.9^T4U=0.76-0.83] k 2 n 111 pr 0.02: 8.2 bits
# exceptions_bits| [[T3=<0.9^T4U=<0.76] V [T3=<0.9^T4U=0.76-0.83^age=70.0-76.0]]...:
#  N 2530 p 273 fp 59 fn 14: exceptions_bits 340
# subset 0-39 | dl: 791
# rule theory bits| [T3=<0.9^T4U=<0.76^TT4=63.0-78.0] k 3 n 111 pr 0.03: 11.5 bits
# exceptions_bits| [[T3=<0.9^T4U=<0.76] V [T3=<0.9^T4U=0.76-0.83^age=70.0-76.0]]...:
#  N 2530 p 273 fp 59 fn 14: exceptions_bits 340
# subset 0-40 | dl: 803
# rule theory bits| [T3=<0.9^T4U=<0.76^FTI=136.0-166.0] k 3 n 111 pr 0.03: 11.5 bits
# exceptions_bits| [[T3=<0.9^T4U=<0.76] V [T3=<0.9^T4U=0.76-0.83^age=70.0-76.0]]...:
#  N 2530 p 273 fp 59 fn 14: exceptions_bits 340
# subset 0-41 | dl: 814
# rule theory bits| [T3=<0.9^TSH=1.18-1.8] k 2 n 111 pr 0.02: 8.2 bits
# exceptions_bits| [[T3=<0.9^T4U=<0.76] V [T3=<0.9^T4U=0.76-0.83^age=70.0-76.0]]...:
#  N 2530 p 273 fp 59 fn 14: exceptions_bits 340
# subset 0-42 | dl: 823
# rule theory bits| [T3=0.9-1.2^FTI=122.0-136.0] k 2 n 111 pr 0.02: 8.2 bits
# exceptions_bits| [[T3=<0.9^T4U=<0.76] V [T3=<0.9^T4U=0.76-0.83^age=70.0-76.0]]...:
#  N 2530 p 273 fp 59 fn 14: exceptions_bits 340
# subset 0-43 | dl: 831
# rule theory bits| [T3=0.9-1.2^FTI=107.0-114.0^T4U=<0.76] k 3 n 111 pr 0.03: 11.5 bits
# exceptions_bits| [[T3=<0.9^T4U=<0.76] V [T3=<0.9^T4U=0.76-0.83^age=70.0-76.0]]...:
#  N 2530 p 273 fp 59 fn 14: exceptions_bits 340
# subset 0-44 | dl: 842
# rule theory bits| [T3=<0.9^T4U=<0.76^on_thyroxine=f^FTI=71.0-86.0] k 4 n 111 pr 0.04: 14.4 bits
# exceptions_bits| [[T3=<0.9^T4U=<0.76] V [T3=<0.9^T4U=0.76-0.83^age=70.0-76.0]]...:
#  N 2530 p 273 fp 59 fn 14: exceptions_bits 340
# subset 0-45 | dl: 857
# subset dls: [(0, 994), (1, 975), (2, 976), (3, 958), (4, 959), (5, 945), (6, 913), (7, 862), (8, 854), (9, 820), (10, 810), (11, 816), (12, 803), (13, 775), (14, 768), (15, 750), (16, 747), (17, 744), (18, 753), (19, 731), (20, 707), (21, 711), (22, 711), (23, 720), (24, 708), (25, 716), (26, 724), (27, 727), (28, 735), (29, 735), (30, 737), (31, 735), (32, 739), (33, 740), (34, 749), (35, 760), (36, 765), (37, 769), (38, 779), (39, 791), (40, 803), (41, 814), (42, 823), (43, 831), (44, 842), (45, 857)]
# best potential ruleset: [[T3=<0.9^T4U=<0.76] V [T3=<0.9^T4U=0.76-0.83^age=70.0-76.0] V [T3=0.9-1.2^T4U=0.88-0.92^TSH=<0.3] V [T3=<0.9^T4U=0.76-0.83^age=64.0-70.0] V [T3=0.9-1.2^FTI=122.0-136.0] V [T3=<0.9^TSH=1.18-1.8] V [T3=0.9-1.2^age=70.0-76.0^sex=M] V [T3=<0.9^TSH=<0.3^sex=F] V [T3=0.9-1.2^FTI=107.0-114.0^T4U=<0.76] V [T3=0.9-1.2^FTI=107.0-114.0^query_hypothyroid=f] V [T3=<0.9^TSH=3.3-9.8] V [T3=0.9-1.2^TSH=<0.3^FTI=86.0-94.0] V [T3=<0.9^FTI=107.0-114.0] V [T3=0.9-1.2^TSH=0.3-0.7^age=64.0-70.0] V [T3=0.9-1.2^TSH=<0.3^TT4=95.0-104.0] V [T3=<0.9^TSH=0.3-0.7] V [T3=<0.9^TSH=1.8-3.3] V [T3=<0.9^TSH=0.7-1.18] V [T3=0.9-1.2^TSH=0.7-1.18^age=70.0-76.0] V [T3=<0.9^FTI=71.0-86.0]]
# best potential dl was 688
#
# FINAL RULESET:
# [[T3=<0.9 ^ T4U=<0.76] V
# [T3=<0.9 ^ T4U=0.76-0.83 ^ age=70.0-76.0] V
# [T3=0.9-1.2 ^ T4U=0.88-0.92 ^ TSH=<0.3] V
# [T3=<0.9 ^ T4U=0.76-0.83 ^ age=64.0-70.0] V
# [T3=0.9-1.2 ^ FTI=122.0-136.0] V
# [T3=<0.9 ^ TSH=1.18-1.8] V
# [T3=0.9-1.2 ^ age=70.0-76.0 ^ sex=M] V
# [T3=<0.9 ^ TSH=<0.3 ^ sex=F] V
# [T3=0.9-1.2 ^ FTI=107.0-114.0 ^ T4U=<0.76] V
# [T3=0.9-1.2 ^ FTI=107.0-114.0 ^ query_hypothyroid=f] V
# [T3=<0.9 ^ TSH=3.3-9.8] V
# [T3=0.9-1.2 ^ TSH=<0.3 ^ FTI=86.0-94.0] V
# [T3=<0.9 ^ FTI=107.0-114.0] V
# [T3=0.9-1.2 ^ TSH=0.3-0.7 ^ age=64.0-70.0] V
# [T3=0.9-1.2 ^ TSH=<0.3 ^ TT4=95.0-104.0] V
# [T3=<0.9 ^ TSH=0.3-0.7] V
# [T3=<0.9 ^ TSH=1.8-3.3] V
# [T3=<0.9 ^ TSH=0.7-1.18] V
# [T3=0.9-1.2 ^ TSH=0.7-1.18 ^ age=70.0-76.0] V
# [T3=<0.9 ^ FTI=71.0-86.0]]
# 0.9448657187993682

# %% [markdown]
# # Audiology (Standardized) Data Set

# %%
df = data.load_audiology()

# %%
df
# Out:
#     age_gt_60       air airBoneGap    ar_c    ar_u        bone boneAbnormal  \
# 0           f      mild          f  normal  normal         NaN            t
# 1           f  moderate          f  normal  normal         NaN            t
# 2           t      mild          t     NaN  absent        mild            t
# 3           t      mild          t     NaN  absent        mild            f
# 4           t      mild          f  normal  normal        mild            t
# ..        ...       ...        ...     ...     ...         ...          ...
# 195         t      mild          f  absent  normal        mild            t
# 196         t      mild          f  normal  absent        mild            f
# 197         f    normal          f  normal  normal  unmeasured            f
# 198         t      mild          f  normal  normal  unmeasured            f
# 199         t    normal          f  normal  normal  unmeasured            f
#
#          bser history_buzzing history_dizziness  ... s_sn_gt_2k s_sn_gt_4k  \
# 0         NaN               f                 f  ...          f          f
# 1         NaN               f                 f  ...          f          f
# 2         NaN               f                 f  ...          f          f
# 3         NaN               f                 f  ...          f          f
# 4         NaN               f                 f  ...          f          f
# ..        ...             ...               ...  ...        ...        ...
# 195       NaN               f                 f  ...          f          f
# 196       NaN               f                 f  ...          f          f
# 197  degraded               f                 f  ...          f          f
# 198       NaN               f                 f  ...          f          f
# 199       NaN               f                 f  ...          f          f
#
#         speech static_normal tymp viith_nerve_signs wave_V_delayed  \
# 0       normal             t    a                 f              f
# 1       normal             t    a                 f              f
# 2       normal             t   as                 f              f
# 3       normal             t    b                 f              f
# 4         good             t    a                 f              f
# ..         ...           ...  ...               ...            ...
# 195  very_good             t    a                 f              f
# 196  very_good             t    c                 f              f
# 197     normal             f    a                 f              f
# 198  very_good             t    a                 f              f
# 199     normal             t    a                 f              f
#
#     waveform_ItoV_prolonged indentifier                            Class
# 0                         f          p1                 cochlear_unknown
# 1                         f          p2                 cochlear_unknown
# 2                         f          p3      mixed_cochlear_age_fixation
# 3                         f          p4  mixed_cochlear_age_otitis_media
# 4                         f          p5                     cochlear_age
# ..                      ...         ...                              ...
# 195                       f        p196                     cochlear_age
# 196                       f        p197  mixed_cochlear_age_otitis_media
# 197                       f        p198      possible_brainstem_disorder
# 198                       f        p199                     cochlear_age
# 199                       f        p200                     cochlear_age
#
# [200 rows x 71 columns]

# %%
# Equivalent prompt
X_train, X_test = train_test_split(df, test_size = 0.2)

# %%
X_train
# Out:
#     age_gt_60     air airBoneGap      ar_c      ar_u        bone boneAbnormal  \
# 29          f    mild          f  elevated    normal        mild            t
# 192         t  normal          f    normal    normal  unmeasured            f
# 2           t    mild          t       NaN    absent        mild            t
# 115         t  normal          f    absent    absent      normal            f
# 14          t    mild          f    normal    normal        mild            t
# ..        ...     ...        ...       ...       ...         ...          ...
# 32          f  normal          f    normal  elevated         NaN            f
# 40          t  normal          f  elevated    normal         NaN            f
# 177         t    mild          f    normal    normal  unmeasured            f
# 27          f    mild          f    normal    normal         NaN            t
# 160         t    mild          f    normal    normal         NaN            f
#
#     bser history_buzzing history_dizziness  ... s_sn_gt_2k s_sn_gt_4k  \
# 29   NaN               f                 f  ...          f          f
# 192  NaN               f                 f  ...          f          f
# 2    NaN               f                 f  ...          f          f
# 115  NaN               f                 f  ...          f          f
# 14   NaN               f                 f  ...          f          f
# ..   ...             ...               ...  ...        ...        ...
# 32   NaN               f                 f  ...          f          f
# 40   NaN               f                 f  ...          f          f
# 177  NaN               f                 f  ...          f          f
# 27   NaN               f                 f  ...          f          t
# 160  NaN               f                 f  ...          f          f
#
#         speech static_normal tymp viith_nerve_signs wave_V_delayed  \
# 29      normal             t    a                 f              f
# 192       good             t    a                 f              f
# 2       normal             t   as                 f              f
# 115       poor             t    b                 f              f
# 14   very_good             t    a                 f              f
# ..         ...           ...  ...               ...            ...
# 32        good             t    a                 f              f
# 40   very_good             t    a                 f              f
# 177  very_good             t    a                 f              f
# 27      normal             t    a                 f              f
# 160        NaN             t    a                 f              f
#
#     waveform_ItoV_prolonged indentifier                        Class
# 29                        f         p30             cochlear_unknown
# 192                       f        p193       cochlear_age_and_noise
# 2                         f          p3  mixed_cochlear_age_fixation
# 115                       f        p116      mixed_cochlear_age_s_om
# 14                        f         p15                 cochlear_age
# ..                      ...         ...                          ...
# 32                        f         p33             cochlear_unknown
# 40                        f         p41                 cochlear_age
# 177                       f        p178                 cochlear_age
# 27                        f         p28          cochlear_poss_noise
# 160                       f        p161       cochlear_age_and_noise
#
# [160 rows x 71 columns]

# %%
df.Class.unique()
# Out:
# array(['cochlear_unknown', 'mixed_cochlear_age_fixation',
#        'mixed_cochlear_age_otitis_media', 'cochlear_age', 'normal_ear',
#        'cochlear_poss_noise', 'cochlear_age_and_noise',
#        'acoustic_neuroma', 'mixed_cochlear_unk_ser_om',
#        'conductive_discontinuity', 'retrocochlear_unknown',
#        'conductive_fixation', 'bells_palsy',
#        'cochlear_noise_and_heredity', 'mixed_cochlear_unk_fixation',
#        'mixed_poss_noise_om', 'otitis_media', 'possible_menieres',
#        'possible_brainstem_disorder', 'cochlear_age_plus_poss_menieres',
#        'mixed_cochlear_age_s_om', 'mixed_cochlear_unk_discontinuity',
#        'mixed_poss_central_om', 'poss_central'], dtype=object)

# %%
X_test.shape
# Out:
# (40, 71)

# %%
# When working with multiclass classification we start off by separating the least represented classes

for cl in df.Class.unique():
    count = (df.Class == cl).sum()
    print(str(cl) + ': ' + str(count))
# Out:
# cochlear_unknown: 48
# mixed_cochlear_age_fixation: 1
# mixed_cochlear_age_otitis_media: 4
# cochlear_age: 46
# normal_ear: 20
# cochlear_poss_noise: 16
# cochlear_age_and_noise: 18
# acoustic_neuroma: 1
# mixed_cochlear_unk_ser_om: 3
# conductive_discontinuity: 2
# retrocochlear_unknown: 2
# conductive_fixation: 6
# bells_palsy: 1
# cochlear_noise_and_heredity: 2
# mixed_cochlear_unk_fixation: 5
# mixed_poss_noise_om: 2
# otitis_media: 4
# possible_menieres: 8
# possible_brainstem_disorder: 4
# cochlear_age_plus_poss_menieres: 1
# mixed_cochlear_age_s_om: 2
# mixed_cochlear_unk_discontinuity: 2
# mixed_poss_central_om: 1
# poss_central: 1

# %%
acc = []

for i in range(n_rep):
    X_train, X_test = train_test_split(df, test_size = 0.1)
    ripper_clf = lw.RIPPER(k=2)
    ripper_clf.fit(X_train, class_feat = 'Class', pos_class = 'cochlear_poss_noise')
    y_test = X_test['Class']
    score = ripper_clf.score(X_test, y_test)
    acc += [score]
    
np.mean(acc)
# Out:
# 0.9700000000000001

# %% [markdown]
# # Autism Screening Adult Data Set

# %%
df = data.load_autism_screening()

# %%
df
# Out:
#     A1_Score A2_Score A3_Score A4_Score A5_Score A6_Score A7_Score A8_Score  \
# 0          1        1        1        1        0        0        1        1
# 1          1        1        0        1        0        0        0        1
# 2          1        1        0        1        1        0        1        1
# 3          1        1        0        1        0        0        1        1
# 4          1        0        0        0        0        0        0        1
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 699        0        1        0        1        1        0        1        1
# 700        1        0        0        0        0        0        0        1
# 701        1        0        1        1        1        0        1        1
# 702        1        0        0        1        1        0        1        0
# 703        1        0        1        1        1        0        1        1
#
#     A9_Score A10_Score  ...  gender       ethnicity jundice austim  \
# 0          0         0  ...       f  White-European      no     no
# 1          0         1  ...       m          Latino      no    yes
# 2          1         1  ...       m          Latino     yes    yes
# 3          0         1  ...       f  White-European      no    yes
# 4          0         0  ...       f            None      no     no
# ..       ...       ...  ...     ...             ...     ...    ...
# 699        1         1  ...       f  White-European      no     no
# 700        0         1  ...       m        Hispanic      no     no
# 701        0         1  ...       f            None      no     no
# 702        1         1  ...       m     South Asian      no     no
# 703        1         1  ...       f  White-European      no     no
#
#      contry_of_res used_app_before result     age_desc relation Class/ASD
# 0    United States              no    6.0  18 and more     Self        NO
# 1           Brazil              no    5.0  18 and more     Self        NO
# 2            Spain              no    8.0  18 and more   Parent       YES
# 3    United States              no    6.0  18 and more     Self        NO
# 4            Egypt              no    2.0  18 and more     None        NO
# ..             ...             ...    ...          ...      ...       ...
# 699         Russia              no    7.0  18 and more     Self       YES
# 700         Mexico              no    3.0  18 and more   Parent        NO
# 701         Russia              no    7.0  18 and more     None       YES
# 702       Pakistan              no    6.0  18 and more     Self        NO
# 703         Cyprus              no    8.0  18 and more     Self       YES
#
# [704 rows x 21 columns]

# %%
# Equivalent prompt
X_train, X_test = train_test_split(df, test_size = 0.2)

# %%
X_train.shape
# Out:
# (563, 21)

# %%
(df['Class/ASD'] == 'YES').sum()
# Out:
# 189

# %%
acc = []

for i in range(n_rep):
    X_train, X_test = train_test_split(df, test_size = 0.2)
    ripper_clf = lw.RIPPER(k=2)
    ripper_clf.fit(X_train, class_feat = 'Class/ASD', pos_class = 'YES')
    y_test = X_test['Class/ASD']
    score = ripper_clf.score(X_test, y_test)
    acc += [score]
    
np.mean(acc)
# Out:
# 0.999645390070922

# %% [markdown]
# #  Adult Data Set

# %%
df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data')

# %%
df
# Out:
#        39          State-gov   77516    Bachelors   13        Never-married  \
# 0      50   Self-emp-not-inc   83311    Bachelors   13   Married-civ-spouse
# 1      38            Private  215646      HS-grad    9             Divorced
# 2      53            Private  234721         11th    7   Married-civ-spouse
# 3      28            Private  338409    Bachelors   13   Married-civ-spouse
# 4      37            Private  284582      Masters   14   Married-civ-spouse
# ...    ..                ...     ...          ...  ...                  ...
# 32555  27            Private  257302   Assoc-acdm   12   Married-civ-spouse
# 32556  40            Private  154374      HS-grad    9   Married-civ-spouse
# 32557  58            Private  151910      HS-grad    9              Widowed
# 32558  22            Private  201490      HS-grad    9        Never-married
# 32559  52       Self-emp-inc  287927      HS-grad    9   Married-civ-spouse
#
#              Adm-clerical   Not-in-family   White     Male   2174   0   40  \
# 0         Exec-managerial         Husband   White     Male      0   0   13
# 1       Handlers-cleaners   Not-in-family   White     Male      0   0   40
# 2       Handlers-cleaners         Husband   Black     Male      0   0   40
# 3          Prof-specialty            Wife   Black   Female      0   0   40
# 4         Exec-managerial            Wife   White   Female      0   0   40
# ...                   ...             ...     ...      ...    ...  ..  ...
# 32555        Tech-support            Wife   White   Female      0   0   38
# 32556   Machine-op-inspct         Husband   White     Male      0   0   40
# 32557        Adm-clerical       Unmarried   White   Female      0   0   40
# 32558        Adm-clerical       Own-child   White     Male      0   0   20
# 32559     Exec-managerial            Wife   White   Female  15024   0   40
#
#         United-States   <=50K
# 0       United-States   <=50K
# 1       United-States   <=50K
# 2       United-States   <=50K
# 3                Cuba   <=50K
# 4       United-States   <=50K
# ...               ...     ...
# 32555   United-States   <=50K
# 32556   United-States    >50K
# 32557   United-States   <=50K
# 32558   United-States   <=50K
# 32559   United-States    >50K
#
# [32560 rows x 15 columns]

# %%
X_train, X_test = train_test_split(df, test_size = 0.2)

# %%
X_train.shape
# Out:
# (26048, 15)

# %%
(df[' <=50K'] == ' <=50K').sum()
# Out:
# 24719

# %%
acc = []

for i in range(n_rep):
    X_train, X_test = train_test_split(df, test_size = 0.2)
    ripper_clf = lw.RIPPER(k=2)
    ripper_clf.fit(X_train, class_feat = ' <=50K', pos_class = ' <=50K')
    y_test = X_test[' <=50K']
    score = ripper_clf.score(X_test, y_test)
    acc += [score]
    
np.mean(acc)
# Out:
# 0.6971514127764128

# %% [markdown]
# ##   Arrhythmia Data Set

# %%
df = data.load_arrhythmia()

# %%
df
# Out:
#      Age  Sex  Height  Weight  QRS_Dur  P-R_Int  Q-T_Int  T_Int  P_Int  QRS  \
# 0     75    0     190      80       91      193      371    174    121  -16
# 1     56    1     165      64       81      174      401    149     39   25
# 2     54    0     172      95      138      163      386    185    102   96
# 3     55    0     175      94      100      202      380    179    143   28
# 4     75    0     190      80       88      181      360    177    103  -16
# ..   ...  ...     ...     ...      ...      ...      ...    ...    ...  ...
# 447   53    1     160      70       80      199      382    154    117  -37
# 448   37    0     190      85      100      137      361    201     73   86
# 449   36    0     166      68      108      176      365    194    116  -85
# 450   32    1     155      55       93      106      386    218     63   54
# 451   78    1     160      70       79      127      364    138     78   28
#
#      ...  V6271  V6272  V6273  V6274  V6275  V6276  V6277  V6278  V6279  \
# 0    ...    0.0    9.0   -0.9    0.0    0.0    0.9    2.9   23.3   49.4
# 1    ...    0.0    8.5    0.0    0.0    0.0    0.2    2.1   20.4   38.8
# 2    ...    0.0    9.5   -2.4    0.0    0.0    0.3    3.4   12.3   49.0
# 3    ...    0.0   12.2   -2.2    0.0    0.0    0.4    2.6   34.6   61.6
# 4    ...    0.0   13.1   -3.6    0.0    0.0   -0.1    3.9   25.4   62.8
# ..   ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 447  ...    0.0    4.3   -5.0    0.0    0.0    0.7    0.6   -4.4   -0.5
# 448  ...    0.0   15.6   -1.6    0.0    0.0    0.4    2.4   38.0   62.4
# 449  ...    0.0   16.3  -28.6    0.0    0.0    1.5    1.0  -44.2  -33.2
# 450  ...   -0.4   12.0   -0.7    0.0    0.0    0.5    2.4   25.0   46.6
# 451  ...    0.0   10.4   -1.8    0.0    0.0    0.5    1.6   21.3   32.8
#
#      diagnosis
# 0            8
# 1            6
# 2           10
# 3            1
# 4            7
# ..         ...
# 447          1
# 448         10
# 449          2
# 450          1
# 451          1
#
# [452 rows x 280 columns]

# %%
# When the diagnosis is 16, it means that the patient wasn't classified. We remove these observations

df = df.loc[df.diagnosis != 16]

# %%
acc = []

for i in range(n_rep):
    X_train, X_test = train_test_split(df, test_size = 0.1)
    ripper_clf = lw.RIPPER(k=2)
    ripper_clf.fit(X_train, class_feat = 'diagnosis', pos_class = 1)
    y_test = X_test['diagnosis']
    score = ripper_clf.score(X_test, y_test)
    acc += [score]
    
np.mean(acc)
