# %% [markdown]
# We run tests on some benchmark problems using standard RIPPERk

# %%
import numpy as np
import pandas as pd
import scipy

# %%
import uci_dataset as data

# %%
import random
random.seed(10)

# %%
# The results will depend on the random train-test split, so we average the accuracies over a certain number of repetitions
n_rep = 20

# %% [markdown]
# # Thyroid dataset

# %%
df = data.load_thyroid_disease()

# %%
df.columns
# Out:
# Index(['sick-euthyroid', 'age', 'sex', 'on_thyroxine', 'query_on_thyroxine',
#        'on_antithyroid_medication', 'thyroid_surgery', 'query_hypothyroid',
#        'query_hyperthyroid', 'pregnant', 'sick', 'tumor', 'lithium', 'goitre',
#        'TSH_measured', 'TSH', 'T3_measured', 'T3', 'TT4_measured', 'TT4',
#        'T4U_measured', 'T4U', 'FTI_measured', 'FTI', 'TBG_measured', 'TBG'],
#       dtype='object')

# %%
import wittgenstein_change_encod as lw

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
X = df

# %%
X_train, X_test = train_test_split(df, test_size = 0.2)

# %%
X_train
# Out:
#      sick-euthyroid   age sex on_thyroxine query_on_thyroxine  \
# 1999       negative  18.0   F            f                  f
# 1437       negative  45.0   F            f                  f
# 1390       negative  76.0   M            f                  f
# 1255       negative   NaN   F            f                  f
# 3036       negative  19.0   F            f                  f
# ...             ...   ...  ..          ...                ...
# 1880       negative  56.0   M            t                  f
# 1976       negative  78.0   F            f                  f
# 808        negative  38.0   F            f                  f
# 2285       negative  63.0   M            f                  f
# 1003       negative  61.0   F            t                  f
#
#      on_antithyroid_medication thyroid_surgery query_hypothyroid  \
# 1999                         f               f                 f
# 1437                         f               f                 f
# 1390                         f               f                 f
# 1255                         f               f                 f
# 3036                         f               f                 f
# ...                        ...             ...               ...
# 1880                         f               f                 f
# 1976                         f               f                 f
# 808                          f               f                 f
# 2285                         f               f                 f
# 1003                         f               f                 f
#
#      query_hyperthyroid pregnant  ... T3_measured   T3 TT4_measured    TT4  \
# 1999                  f        f  ...           y  3.0            y  143.0
# 1437                  f        f  ...           n  NaN            n    NaN
# 1390                  f        f  ...           y  1.5            y  125.0
# 1255                  f        f  ...           y  2.1            y   96.0
# 3036                  f        f  ...           y  3.1            y  118.0
# ...                 ...      ...  ...         ...  ...          ...    ...
# 1880                  f        f  ...           n  NaN            y  109.0
# 1976                  f        f  ...           y  2.1            y  102.0
# 808                   f        f  ...           y  1.0            y   77.0
# 2285                  f        f  ...           n  NaN            n    NaN
# 1003                  f        f  ...           n  NaN            y  177.0
#
#      T4U_measured   T4U FTI_measured    FTI TBG_measured   TBG
# 1999            y  1.32            y  108.0            n   NaN
# 1437            n   NaN            n    NaN            y  24.0
# 1390            y  0.75            y  165.0            n   NaN
# 1255            y  0.92            y  104.0            n   NaN
# 3036            y  1.06            y  112.0            n   NaN
# ...           ...   ...          ...    ...          ...   ...
# 1880            y  0.92            y  119.0            n   NaN
# 1976            y  1.00            y  101.0            n   NaN
# 808             y  0.80            y   96.0            n   NaN
# 2285            n   NaN            n    NaN            y  23.0
# 1003            y  0.95            y  186.0            n   NaN
#
# [2530 rows x 26 columns]

# %%
X_train['sick-euthyroid'].unique()
# Out:
# array(['negative', 'sick-euthyroid'], dtype=object)

# %%
acc = []

for i in range(n_rep):
    X_train, X_test = train_test_split(df, test_size = 0.2)
    ripper_clf = lw.RIPPER(k=2, verbosity = 5)
    ripper_clf.fit(X_train, class_feat = 'sick-euthyroid', pos_class = 'sick-euthyroid')
    y_test = X_test['sick-euthyroid']
    score = ripper_clf.score(X_test, y_test)
    acc += [score]
    
np.mean(acc)
# Out:
# age: fit 92 unique vals into 10 bins
# TSH: fit 219 unique vals into 7 bins
# T3: fit 66 unique vals into 10 bins
# TT4: fit 254 unique vals into 10 bins
# T4U: fit 155 unique vals into 10 bins
# FTI: fit 256 unique vals into 10 bins
# TBG: fit 49 unique vals into 10 bins
# growing ruleset...
# initial model: []
#
# pos_growset 158 pos_pruneset 79
# neg_growset 1536 neg_pruneset 757
# growing rule from initial rule: [True]
# gain 265 T3=<0.9
# negs remaining: 52
# gain 15.3 TSH=<0.3
# negs remaining: 4
# gain 1.4 age=70.0-76.0
# negs remaining: 0
# grew rule: [T3=<0.9^TSH=<0.3^age=70.0-76.0]
# prune value of [T3=<0.9^TSH=<0.3^age=70.0-76.0]: 1
# prune value of [T3=<0.9^TSH=<0.3]: 0.6
# prune value of [T3=<0.9]: 0.18
# pruned rule unchanged
# updated ruleset: [None]
#
# rule theory bits| [T3=<0.9^TSH=<0.3^age=70.0-76.0] k 3 n 111 pr 0.03: 11.5 bits
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-f86328f84178> in <module>
#       4     X_train, X_test = train_test_split(df, test_size = 0.2)
#       5     ripper_clf = lw.RIPPER(k=2, verbosity = 5)
# ----> 6     ripper_clf.fit(X_train, class_feat = 'sick-euthyroid', pos_class = 'sick-euthyroid')
#       7     y_test = X_test['sick-euthyroid']
#       8     score = ripper_clf.score(X_test, y_test)
#
# ~\Desktop\Statistics and data Science\Master Thesis\wittgenstein_change_encod\ripper.py in fit(self, trainset, y, class_feat, pos_class, feature_names, initial_model, cn_optimize, **kwargs)
#     215             pos_idx = set(pos_df.index.tolist())
#     216             neg_idx = set(neg_df.index.tolist())
# --> 217             self.ruleset_ = self._grow_ruleset_cn(
#     218                 pos_idx,
#     219                 neg_idx,
#
# ~\Desktop\Statistics and data Science\Master Thesis\wittgenstein_change_encod\ripper.py in _grow_ruleset_cn(self, pos_idx, neg_idx, prune_size, dl_allowance, max_rules, max_rule_conds, max_total_conds, initial_model, random_state)
#     620                 )
#     621                 theory_dl = rule_dl
# --> 622                 data_dl = _exceptions_bits_cn(
#     623                     self.cn, ruleset, pos_idx, neg_idx, verbosity=self.verbosity
#     624                 )
#
# ~\Desktop\Statistics and data Science\Master Thesis\wittgenstein_change_encod\ripper.py in _exceptions_bits_cn(cn, ruleset, pos_idx, neg_idx, verbosity)
#    1274     #    raise TypeError(f'to avoid double-counting, _exceptions_bits should calculate exceptions over entire set of rules with type Ruleset')
#    1275     N = len(pos_idx) + len(neg_idx)  # Total number of examples
# -> 1276     pos_cov = cn.ruleset_covers(ruleset, subset=pos_idx)
#    1277     neg_cov = cn.ruleset_covers(ruleset, subset=neg_idx)
#    1278     p = len(pos_cov) + len(
#
# ~\Desktop\Statistics and data Science\Master Thesis\wittgenstein_change_encod\catnap.py in ruleset_covers(self, ruleset, subset)
#      74
#      75     def ruleset_covers(self, ruleset, subset=None):
# ---> 76         allpos, allneg = ruleset._check_allpos_allneg(warn=False)
#      77         if allpos:
#      78             return self.all if not subset else subset
#
# ~\Desktop\Statistics and data Science\Master Thesis\wittgenstein_change_encod\base.py in _check_allpos_allneg(self, warn, warnstack)
#     313     def _check_allpos_allneg(self, warn=False, warnstack=""):
#     314         """Check if a Ruleset is universal (always predicts pos) or empty (always predicts neg) """
# --> 315         if self.isuniversal() and warn:
#     316             warning_str = f"Ruleset is universal. All predictions it makes with method .predict will be positive. It may be untrained or was trained on a dataset split lacking negative examples."
#     317             _warn(
#
# ~\Desktop\Statistics and data Science\Master Thesis\wittgenstein_change_encod\base.py in isuniversal(self)
#      96         """Return whether the Ruleset has an empty rule, i.e. it will always return positive predictions."""
#      97         if len(self.rules) >= 1:
# ---> 98             return all(rule.isempty() for rule in self.rules)
#      99         else:
#     100             return False
#
# ~\Desktop\Statistics and data Science\Master Thesis\wittgenstein_change_encod\base.py in <genexpr>(.0)
#      96         """Return whether the Ruleset has an empty rule, i.e. it will always return positive predictions."""
#      97         if len(self.rules) >= 1:
# ---> 98             return all(rule.isempty() for rule in self.rules)
#      99         else:
#     100             return False
#
# AttributeError: 'NoneType' object has no attribute 'isempty'

# %% [markdown]
# # Audiology (Standardized) Data Set

# %%
df = data.load_audiology()

# %%
df
# Out:
#     age_gt_60       air airBoneGap    ar_c    ar_u        bone boneAbnormal  \
# 0           f      mild          f  normal  normal         NaN            t
# 1           f  moderate          f  normal  normal         NaN            t
# 2           t      mild          t     NaN  absent        mild            t
# 3           t      mild          t     NaN  absent        mild            f
# 4           t      mild          f  normal  normal        mild            t
# ..        ...       ...        ...     ...     ...         ...          ...
# 195         t      mild          f  absent  normal        mild            t
# 196         t      mild          f  normal  absent        mild            f
# 197         f    normal          f  normal  normal  unmeasured            f
# 198         t      mild          f  normal  normal  unmeasured            f
# 199         t    normal          f  normal  normal  unmeasured            f
#
#          bser history_buzzing history_dizziness  ... s_sn_gt_2k s_sn_gt_4k  \
# 0         NaN               f                 f  ...          f          f
# 1         NaN               f                 f  ...          f          f
# 2         NaN               f                 f  ...          f          f
# 3         NaN               f                 f  ...          f          f
# 4         NaN               f                 f  ...          f          f
# ..        ...             ...               ...  ...        ...        ...
# 195       NaN               f                 f  ...          f          f
# 196       NaN               f                 f  ...          f          f
# 197  degraded               f                 f  ...          f          f
# 198       NaN               f                 f  ...          f          f
# 199       NaN               f                 f  ...          f          f
#
#         speech static_normal tymp viith_nerve_signs wave_V_delayed  \
# 0       normal             t    a                 f              f
# 1       normal             t    a                 f              f
# 2       normal             t   as                 f              f
# 3       normal             t    b                 f              f
# 4         good             t    a                 f              f
# ..         ...           ...  ...               ...            ...
# 195  very_good             t    a                 f              f
# 196  very_good             t    c                 f              f
# 197     normal             f    a                 f              f
# 198  very_good             t    a                 f              f
# 199     normal             t    a                 f              f
#
#     waveform_ItoV_prolonged indentifier                            Class
# 0                         f          p1                 cochlear_unknown
# 1                         f          p2                 cochlear_unknown
# 2                         f          p3      mixed_cochlear_age_fixation
# 3                         f          p4  mixed_cochlear_age_otitis_media
# 4                         f          p5                     cochlear_age
# ..                      ...         ...                              ...
# 195                       f        p196                     cochlear_age
# 196                       f        p197  mixed_cochlear_age_otitis_media
# 197                       f        p198      possible_brainstem_disorder
# 198                       f        p199                     cochlear_age
# 199                       f        p200                     cochlear_age
#
# [200 rows x 71 columns]

# %%
# Equivalent prompt
X_train, X_test = train_test_split(df, test_size = 0.2)

# %%
X_train
# Out:
#     age_gt_60       air airBoneGap    ar_c      ar_u        bone boneAbnormal  \
# 18          f    normal          f  normal    normal         NaN            f
# 71          f    normal          f  absent    normal      normal            f
# 98          f      mild          f  normal    normal         NaN            f
# 37          f    normal          f  absent  elevated      normal            f
# 178         t    normal          f  normal    normal  unmeasured            f
# ..        ...       ...        ...     ...       ...         ...          ...
# 187         f      mild          f  normal    normal        mild            f
# 144         t      mild          f  normal    normal         NaN            f
# 194         t      mild          f  normal  elevated  unmeasured            f
# 138         t  moderate          f  normal    normal         NaN            t
# 86          f      mild          t  absent    absent         NaN            f
#
#     bser history_buzzing history_dizziness  ... s_sn_gt_2k s_sn_gt_4k  \
# 18   NaN               f                 f  ...          f          f
# 71   NaN               f                 f  ...          f          f
# 98   NaN               f                 t  ...          f          f
# 37   NaN               f                 f  ...          f          f
# 178  NaN               f                 f  ...          f          f
# ..   ...             ...               ...  ...        ...        ...
# 187  NaN               f                 f  ...          f          f
# 144  NaN               f                 f  ...          f          f
# 194  NaN               f                 f  ...          f          f
# 138  NaN               f                 f  ...          f          f
# 86   NaN               f                 f  ...          f          f
#
#         speech static_normal tymp viith_nerve_signs wave_V_delayed  \
# 18      normal             t    a                 f              f
# 71      normal             t    a                 f              f
# 98      normal             t    a                 f              f
# 37      normal             t    a                 f              f
# 178     normal             t    a                 f              f
# ..         ...           ...  ...               ...            ...
# 187       poor             t    a                 f              f
# 144     normal             t    a                 f              f
# 194  very_good             t    a                 f              f
# 138  very_poor             t    a                 f              f
# 86      normal             t    b                 f              f
#
#     waveform_ItoV_prolonged indentifier                   Class
# 18                        f         p19              normal_ear
# 71                        f         p72              normal_ear
# 98                        f         p99        cochlear_unknown
# 37                        f         p38              normal_ear
# 178                       f        p179            cochlear_age
# ..                      ...         ...                     ...
# 187                       f        p188        cochlear_unknown
# 144                       f        p145            cochlear_age
# 194                       f        p195            cochlear_age
# 138                       f        p139  cochlear_age_and_noise
# 86                        f         p87            otitis_media
#
# [160 rows x 71 columns]

# %%
df.Class.unique()
# Out:
# array(['cochlear_unknown', 'mixed_cochlear_age_fixation',
#        'mixed_cochlear_age_otitis_media', 'cochlear_age', 'normal_ear',
#        'cochlear_poss_noise', 'cochlear_age_and_noise',
#        'acoustic_neuroma', 'mixed_cochlear_unk_ser_om',
#        'conductive_discontinuity', 'retrocochlear_unknown',
#        'conductive_fixation', 'bells_palsy',
#        'cochlear_noise_and_heredity', 'mixed_cochlear_unk_fixation',
#        'mixed_poss_noise_om', 'otitis_media', 'possible_menieres',
#        'possible_brainstem_disorder', 'cochlear_age_plus_poss_menieres',
#        'mixed_cochlear_age_s_om', 'mixed_cochlear_unk_discontinuity',
#        'mixed_poss_central_om', 'poss_central'], dtype=object)

# %%
X_test.shape
# Out:
# (40, 71)

# %%
# When working with multiclass classification we start off by separating the least represented classes

for cl in df.Class.unique():
    count = (df.Class == cl).sum()
    print(str(cl) + ': ' + str(count))
# Out:
# cochlear_unknown: 48
# mixed_cochlear_age_fixation: 1
# mixed_cochlear_age_otitis_media: 4
# cochlear_age: 46
# normal_ear: 20
# cochlear_poss_noise: 16
# cochlear_age_and_noise: 18
# acoustic_neuroma: 1
# mixed_cochlear_unk_ser_om: 3
# conductive_discontinuity: 2
# retrocochlear_unknown: 2
# conductive_fixation: 6
# bells_palsy: 1
# cochlear_noise_and_heredity: 2
# mixed_cochlear_unk_fixation: 5
# mixed_poss_noise_om: 2
# otitis_media: 4
# possible_menieres: 8
# possible_brainstem_disorder: 4
# cochlear_age_plus_poss_menieres: 1
# mixed_cochlear_age_s_om: 2
# mixed_cochlear_unk_discontinuity: 2
# mixed_poss_central_om: 1
# poss_central: 1

# %%
acc = []

for i in range(n_rep):
    X_train, X_test = train_test_split(df, test_size = 0.2)
    ripper_clf = lw.RIPPER(k=2)
    ripper_clf.fit(X_train, class_feat = 'Class', pos_class = 'cochlear_poss_noise')
    y_test = X_test['Class']
    score = ripper_clf.score(X_test, y_test)
    acc += [score]
    
np.mean(acc)
# Out:
# 0.96

# %% [markdown]
# # Autism Screening Adult Data Set

# %%
df = data.load_autism_screening()

# %%
df
# Out:
#     A1_Score A2_Score A3_Score A4_Score A5_Score A6_Score A7_Score A8_Score  \
# 0          1        1        1        1        0        0        1        1
# 1          1        1        0        1        0        0        0        1
# 2          1        1        0        1        1        0        1        1
# 3          1        1        0        1        0        0        1        1
# 4          1        0        0        0        0        0        0        1
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 699        0        1        0        1        1        0        1        1
# 700        1        0        0        0        0        0        0        1
# 701        1        0        1        1        1        0        1        1
# 702        1        0        0        1        1        0        1        0
# 703        1        0        1        1        1        0        1        1
#
#     A9_Score A10_Score  ...  gender       ethnicity jundice austim  \
# 0          0         0  ...       f  White-European      no     no
# 1          0         1  ...       m          Latino      no    yes
# 2          1         1  ...       m          Latino     yes    yes
# 3          0         1  ...       f  White-European      no    yes
# 4          0         0  ...       f            None      no     no
# ..       ...       ...  ...     ...             ...     ...    ...
# 699        1         1  ...       f  White-European      no     no
# 700        0         1  ...       m        Hispanic      no     no
# 701        0         1  ...       f            None      no     no
# 702        1         1  ...       m     South Asian      no     no
# 703        1         1  ...       f  White-European      no     no
#
#      contry_of_res used_app_before result     age_desc relation Class/ASD
# 0    United States              no    6.0  18 and more     Self        NO
# 1           Brazil              no    5.0  18 and more     Self        NO
# 2            Spain              no    8.0  18 and more   Parent       YES
# 3    United States              no    6.0  18 and more     Self        NO
# 4            Egypt              no    2.0  18 and more     None        NO
# ..             ...             ...    ...          ...      ...       ...
# 699         Russia              no    7.0  18 and more     Self       YES
# 700         Mexico              no    3.0  18 and more   Parent        NO
# 701         Russia              no    7.0  18 and more     None       YES
# 702       Pakistan              no    6.0  18 and more     Self        NO
# 703         Cyprus              no    8.0  18 and more     Self       YES
#
# [704 rows x 21 columns]

# %%
# Equivalent prompt
X_train, X_test = train_test_split(df, test_size = 0.2)

# %%
X_train.shape
# Out:
# (563, 21)

# %%
(df['Class/ASD'] == 'YES').sum()
# Out:
# 189

# %%
acc = []

for i in range(n_rep):
    X_train, X_test = train_test_split(df, test_size = 0.2)
    ripper_clf = lw.RIPPER(k=2)
    ripper_clf.fit(X_train, class_feat = 'Class/ASD', pos_class = 'YES')
    y_test = X_test['Class/ASD']
    score = ripper_clf.score(X_test, y_test)
    acc += [score]
    
np.mean(acc)
# Out:
# 0.9971631205673759

# %% [markdown]
# #  Adult Data Set

# %%
df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data')

# %%
df
# Out:
#        39          State-gov   77516    Bachelors   13        Never-married  \
# 0      50   Self-emp-not-inc   83311    Bachelors   13   Married-civ-spouse
# 1      38            Private  215646      HS-grad    9             Divorced
# 2      53            Private  234721         11th    7   Married-civ-spouse
# 3      28            Private  338409    Bachelors   13   Married-civ-spouse
# 4      37            Private  284582      Masters   14   Married-civ-spouse
# ...    ..                ...     ...          ...  ...                  ...
# 32555  27            Private  257302   Assoc-acdm   12   Married-civ-spouse
# 32556  40            Private  154374      HS-grad    9   Married-civ-spouse
# 32557  58            Private  151910      HS-grad    9              Widowed
# 32558  22            Private  201490      HS-grad    9        Never-married
# 32559  52       Self-emp-inc  287927      HS-grad    9   Married-civ-spouse
#
#              Adm-clerical   Not-in-family   White     Male   2174   0   40  \
# 0         Exec-managerial         Husband   White     Male      0   0   13
# 1       Handlers-cleaners   Not-in-family   White     Male      0   0   40
# 2       Handlers-cleaners         Husband   Black     Male      0   0   40
# 3          Prof-specialty            Wife   Black   Female      0   0   40
# 4         Exec-managerial            Wife   White   Female      0   0   40
# ...                   ...             ...     ...      ...    ...  ..  ...
# 32555        Tech-support            Wife   White   Female      0   0   38
# 32556   Machine-op-inspct         Husband   White     Male      0   0   40
# 32557        Adm-clerical       Unmarried   White   Female      0   0   40
# 32558        Adm-clerical       Own-child   White     Male      0   0   20
# 32559     Exec-managerial            Wife   White   Female  15024   0   40
#
#         United-States   <=50K
# 0       United-States   <=50K
# 1       United-States   <=50K
# 2       United-States   <=50K
# 3                Cuba   <=50K
# 4       United-States   <=50K
# ...               ...     ...
# 32555   United-States   <=50K
# 32556   United-States    >50K
# 32557   United-States   <=50K
# 32558   United-States   <=50K
# 32559   United-States    >50K
#
# [32560 rows x 15 columns]

# %%
X_train, X_test = train_test_split(df, test_size = 0.2)

# %%
X_train.shape
# Out:
# (26048, 15)

# %%
(df[' <=50K'] == ' <=50K').sum()
# Out:
# 24719

# %%
acc = []

for i in range(n_rep):
    X_train, X_test = train_test_split(df, test_size = 0.2)
    ripper_clf = lw.RIPPER(k=2)
    ripper_clf.fit(X_train, class_feat = ' <=50K', pos_class = ' <=50K')
    y_test = X_test[' <=50K']
    score = ripper_clf.score(X_test, y_test)
    acc += [score]
    
np.mean(acc)
# Out:
# 0.7211455773955774

# %% [markdown]
# ##   Arrhythmia Data Set

# %%
df = data.load_arrhythmia()

# %%
df
# Out:
#      Age  Sex  Height  Weight  QRS_Dur  P-R_Int  Q-T_Int  T_Int  P_Int  QRS  \
# 0     75    0     190      80       91      193      371    174    121  -16
# 1     56    1     165      64       81      174      401    149     39   25
# 2     54    0     172      95      138      163      386    185    102   96
# 3     55    0     175      94      100      202      380    179    143   28
# 4     75    0     190      80       88      181      360    177    103  -16
# ..   ...  ...     ...     ...      ...      ...      ...    ...    ...  ...
# 447   53    1     160      70       80      199      382    154    117  -37
# 448   37    0     190      85      100      137      361    201     73   86
# 449   36    0     166      68      108      176      365    194    116  -85
# 450   32    1     155      55       93      106      386    218     63   54
# 451   78    1     160      70       79      127      364    138     78   28
#
#      ...  V6271  V6272  V6273  V6274  V6275  V6276  V6277  V6278  V6279  \
# 0    ...    0.0    9.0   -0.9    0.0    0.0    0.9    2.9   23.3   49.4
# 1    ...    0.0    8.5    0.0    0.0    0.0    0.2    2.1   20.4   38.8
# 2    ...    0.0    9.5   -2.4    0.0    0.0    0.3    3.4   12.3   49.0
# 3    ...    0.0   12.2   -2.2    0.0    0.0    0.4    2.6   34.6   61.6
# 4    ...    0.0   13.1   -3.6    0.0    0.0   -0.1    3.9   25.4   62.8
# ..   ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 447  ...    0.0    4.3   -5.0    0.0    0.0    0.7    0.6   -4.4   -0.5
# 448  ...    0.0   15.6   -1.6    0.0    0.0    0.4    2.4   38.0   62.4
# 449  ...    0.0   16.3  -28.6    0.0    0.0    1.5    1.0  -44.2  -33.2
# 450  ...   -0.4   12.0   -0.7    0.0    0.0    0.5    2.4   25.0   46.6
# 451  ...    0.0   10.4   -1.8    0.0    0.0    0.5    1.6   21.3   32.8
#
#      diagnosis
# 0            8
# 1            6
# 2           10
# 3            1
# 4            7
# ..         ...
# 447          1
# 448         10
# 449          2
# 450          1
# 451          1
#
# [452 rows x 280 columns]

# %%
# When the diagnosis is 16, it means that the patient wasn't classified. We remove these observations

df = df.loc[df.diagnosis != 16]

# %%
acc = []

for i in range(n_rep):
    X_train, X_test = train_test_split(df, test_size = 0.2)
    ripper_clf = lw.RIPPER(k=2)
    ripper_clf.fit(X_train, class_feat = 'diagnosis', pos_class = 1)
    y_test = X_test['diagnosis']
    score = ripper_clf.score(X_test, y_test)
    acc += [score]
    
np.mean(acc)
# Out:
# 0.5459302325581395
